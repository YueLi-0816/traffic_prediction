# %% [markdown]
# ###  * Data quanlity - temporal

# %% [markdown]
# **827** (861) days available
# - from **2019-08-05** to **2019-10-16** (73d)
# - from **2019-11-20** to **2021-12-12** (754d)
# - data missing from 2019-10-17 to 2019-11-19 (34d)
#
# **79,392** records should be recorded
# <br>
# <br>

# %% [markdown]
# ### * Two steps to recover the data

# %% [markdown]
# (1) create a list/dataframe with entire 79,392 timestamps ('%Y-%m-%d %H:%M:%S')<br>
# (2) extract the timestamps ('%Y-%m-%d %H:%M:%S') from the raw data<br>
# (3) compare the two list/dataframe and do the interpolation for the raw data<br>
# (4) the new data should be the length of 79,392

# %%
import pandas as pd
import numpy as np
import sys
pd.set_option('display.max_colwidth', None)
np.set_printoptions(threshold=sys.maxsize)

# %% [markdown]
# ## 1. Calculate the average and sum traffic flow

# %% [markdown]
# #### &nbsp;&nbsp;&nbsp;&nbsp; Select the sites with highest traffic flow

# %%
detectors = pd.read_csv('../../../Data/Data processing/20211028_SCOOT_Data/JupyterNotebook_CSV/useful_detector_530.csv')
detectors.sort_values(by=['zeroPercentage%'])
# Out:
#        siteId  start_date    end_date  full_dates  practical_dates  \
# 107  GB0701_D  2019-08-05  2021-12-12         861              815
# 216  GD0801_A  2019-08-05  2021-12-12         861              815
# 84   GB0121_B  2019-08-05  2021-12-12         861              815
# 224  GD1351_R  2019-08-05  2021-12-12         861              815
# 117  GB1271_D  2019-08-05  2021-12-12         861              815
# ..        ...         ...         ...         ...              ...
# 138  GC0271_C  2019-08-05  2021-12-12         861              815
# 384  GH3171_G  2019-08-05  2021-12-12         861              815
# 125  GB1371_T  2019-08-05  2021-12-12         861              815
# 401  GH3451_L  2019-08-05  2021-12-12         861              815
# 293  GG2001_V  2019-08-05  2021-12-12         861              815
#
#      consecutive_percentage  zeroPercentage%  \
# 107                0.946574         0.193899
# 216                0.946574         0.615728
# 84                 0.946574         0.688126
# 224                0.946574         0.703467
# 117                0.946574         1.400844
# ..                      ...              ...
# 138                0.946574        55.409429
# 384                0.946574        56.479475
# 125                0.946574        60.635158
# 401                0.946574        61.834867
# 293                0.946574        75.980181
#
#                                       description        lat       lon  \
# 107     Eglinton Street southbound to Cook Street  55.851598 -4.259280
# 216  Woodlands Road Southbound to Lynedoch Street  55.869218 -4.274113
# 84    Wallace Street westbound to Paterson Street  55.852449 -4.265289
# 224                     Balshagray Ave northbound  55.875822 -4.327561
# 117    Hospital Street southbound to Caledonia Rd  55.847902 -4.254001
# ..                                            ...        ...       ...
# 138                                    Ferry Road  55.866117 -4.305051
# 384                                   Dora Street  55.842218 -4.221582
# 125                                 Mosque Avenue  55.851862 -4.250731
# 401                             Sports Arena exit  55.846214 -4.209845
# 293                            New Station Street  55.859530 -4.237368
#
#         easting    northing      type
# 107  258661.087  664353.327  detector
# 216  257797.080  666344.365  detector
# 84   258288.083  664460.333  detector
# 224  254478.044  667190.412  detector
# 117  258978.091  663931.318  detector
# ..          ...         ...       ...
# 138  255850.058  666063.382  detector
# 384  260987.111  663233.287  detector
# 125  259197.093  664365.323  detector
# 401  261736.119  663654.286  detector
# 293  260061.102  665191.327  detector
#
# [530 rows x 13 columns]

# %%
means = []
sums = []
zeroPercent = []
errorNum = []
consecutiveError = []
sites = []

for i in detectors.siteId.tolist():
    print(i)
    site_df = pd.read_csv('../../../Data/Data processing/20211028_SCOOT_Data/JupyterNotebook_CSV/20211213_SCOOT_data/' + i + '&2019_08_05-2021_12_12.csv')
    average_flow = site_df['flow'].mean()
    sum_flow = site_df['flow'].sum()
    zero = detectors.loc[detectors.siteId == i, 'zeroPercentage%'].item()
    error = 79392 - len(site_df)
    error2 = sorted(list(site_df.loc[site_df['count'] > 2, 'count'].unique()), reverse=True)    
    
    means.append(average_flow)
    sums.append(sum_flow)
    zeroPercent.append(zero)
    errorNum.append(error)
    consecutiveError.append(error2)
    sites.append(i)
    
    
flow_stats = {'siteId': sites,
              'averageFlow': means,
              'sumFlow': sums,
              'zeroPercentage(%)': zeroPercent,
              'errorNum': errorNum,
              'consecutiveError': consecutiveError}

flow_stats_df = pd.DataFrame(flow_stats)
# Out:
# GA0151_A
# GA0151_C
# GA0151_D
# GA0401_R
# GA0401_S
# GA0401_T
# GA0571_N
# GA0571_V
# GA058A_B
# GA058A_C
# GA0601_T
# GA0601_V
# GA0651_A
# GA0651_B
# GA0651_C
# GA070A_S
# GA1051_P
# GA1051_S
# GA1321_B
# GA1321_C
# GA1331_V
# GA1361_B
# GA1361_C
# GA1371_R
# GA1371_V
# GA1501_T
# GA1571_Q
# GA1571_T
# GA1601_A
# GA1851_A
# GA1851_C
# GA1851_E
# GA1851_F
# GA2351_T
# GA2401_B
# GA2401_D
# GA2421_W
# GA3221_B
# GA3221_D
# GA4401_M
# GA4401_N
# GA4401_Y
# GA4451_A
# GA4451_C
# GA4451_D
# GA4501_S
# GA4501_T
# GA4501_V
# GA4551_S
# GA4551_T
# GA4551_V
# GA4721_S
# GA4721_T
# GA4751_D
# GA4851_S
# GA4851_V
# GA5151_P
# GA5151_R
# GA5151_T
# GA5151_V
# GA5171_B
# GA5171_D
# GA5201_A
# GA5201_B
# GA5201_D
# GA5251_R
# GA5251_T
# GA5251_V
# GA5301_B
# GA5351_R
# GA5351_T
# GA5371_A
# GA5371_C
# GA5371_D
# GA5371_F
# GA5401_T
# GA5401_V
# GA5401_X
# GA5471_B
# GA5471_C
# GA5471_D
# GA5601_M
# GA5601_N
# GA5601_P
# GB0121_B
# GB0121_D
# GB0141_U
# GB0141_V
# GB0151_C
# GB0151_E
# GB0251_S
# GB0251_T
# GB0301_A
# GB0301_D
# GB0351_S
# GB0351_T
# GB0401_V
# GB0401_X
# GB0501_A
# GB0601_B
# GB0601_C
# GB0601_D
# GB0651_R
# GB0651_T
# GB0651_V
# GB0701_B
# GB0701_C
# GB0701_D
# GB0751_S
# GB0751_T
# GB0751_V
# GB1101_A
# GB1101_B
# GB1101_C
# GB1151_S
# GB1151_V
# GB1271_B
# GB1271_D
# GB1321_M
# GB1351_A
# GB1351_B
# GB1351_C
# GB1351_D
# GB1371_R
# GB1371_S
# GB1371_T
# GB1371_V
# GB145A_R
# GB1601_A
# GB1601_B
# GC0051_E
# GC0051_F
# GC0051_G
# GC0151_A
# GC0151_B
# GC0151_E
# GC0271_A
# GC0271_B
# GL1901_T
# GL3551_R
# GL3551_S
# GL3551_T
# GL4151_B
# GL4151_C

# %%
#merge the coordinates
flow_stats_df = pd.merge(flow_stats_df, detectors[['siteId', 'lat', 'lon', 'easting', 'northing']], on="siteId")

# %%
flow_stats_df.sort_values(by=['sumFlow'], ascending=False)
# Out:
#        siteId  averageFlow  sumFlow  zeroPercentage(%)  errorNum  \
# 224  GD1351_R    54.009658  4261092           0.703467       497
# 228  GD1501_A    44.644864  3522078           5.759846       501
# 216  GD0801_A    41.018168  3237605           0.615728       461
# 107  GB0701_D    35.687873  2816023           0.193899       485
# 84   GB0121_B    35.155227  2774099           0.688126       482
# ..        ...          ...      ...                ...       ...
# 384  GH3171_G     2.158245   170292          56.479475       489
# 401  GH3451_L     1.559612   123044          61.834867       498
# 138  GC0271_C     1.438557   113541          55.409429       465
# 126  GB1371_V     1.425754   112549          52.946542       452
# 293  GG2001_V     1.344210   106077          75.980181       478
#
#                                          consecutiveError        lat  \
# 224  [97, 47, 45, 40, 37, 31, 20, 18, 11, 10, 8, 5, 4, 3]  55.875822
# 228  [97, 47, 45, 40, 37, 31, 21, 18, 11, 10, 8, 5, 4, 3]  55.886188
# 216  [97, 47, 45, 40, 38, 32, 20, 18, 11, 10, 8, 5, 4, 3]  55.869218
# 107  [97, 47, 45, 40, 37, 31, 20, 18, 11, 10, 8, 5, 4, 3]  55.851598
# 84   [97, 47, 45, 40, 37, 31, 20, 18, 11, 10, 8, 5, 4, 3]  55.852449
# ..                                                    ...        ...
# 384  [97, 47, 45, 40, 37, 31, 21, 18, 11, 10, 8, 5, 4, 3]  55.842218
# 401  [97, 47, 45, 40, 37, 31, 21, 18, 11, 10, 8, 5, 4, 3]  55.846214
# 138  [97, 47, 45, 40, 37, 32, 20, 18, 11, 10, 8, 5, 4, 3]  55.866117
# 126  [97, 47, 45, 40, 37, 32, 20, 18, 11, 10, 8, 5, 4, 3]  55.850829
# 293  [97, 47, 45, 40, 37, 32, 21, 18, 11, 10, 8, 5, 4, 3]  55.859530
#
#           lon     easting    northing
# 224 -4.327561  254478.044  667190.412
# 228 -4.325527  254644.044  668339.426
# 216 -4.274113  257797.080  666344.365
# 107 -4.259280  258661.087  664353.327
# 84  -4.265289  258288.083  664460.333
# ..        ...         ...         ...
# 384 -4.221582  260987.111  663233.287
# 401 -4.209845  261736.119  663654.286
# 138 -4.305051  255850.058  666063.382
# 126 -4.251231  259162.093  664251.321
# 293 -4.237368  260061.102  665191.327
#
# [530 rows x 10 columns]

# %% [markdown]
# ## 2. Interpolation

# %% [markdown]
# #### &nbsp;&nbsp;&nbsp;&nbsp; Sites selected: GD1351_R

# %%
data = pd.read_csv('../../../Data/Data processing/20211028_SCOOT_Data/JupyterNotebook_CSV/20211213_SCOOT_data/GD1351_R&2019_08_05-2021_12_12.csv')
data
# Out:
#                          lastUpdate            timestamp siteSiteid  count  \
# 0      2019-08-05T00:00:01.5814024Z  2019-08-05T00:55:11   GD1351_R      1
# 1      2019-08-05T00:15:01.6768137Z  2019-08-05T01:10:11   GD1351_R      1
# 2      2019-08-05T00:30:00.2899954Z  2019-08-05T01:25:11   GD1351_R      1
# 4      movement-5c571e65-c076-490b-bfeb-f82bd5982350  Location     254478.044
# ...                                              ...       ...            ...
# 78890  movement-1c2c1857-1f46-48cf-ad36-b75c01472265  Location     254478.044
# 78891  movement-d4d6ce34-b0a4-4481-ab00-5a4b8d5b29c9  Location     254478.044
# 78892  movement-06777ded-9a05-4101-bd8c-e0e345e069a3  Location     254478.044
# 78893  movement-4081cfcb-a3d4-4674-a84f-caffac24b352  Location     254478.044
# 78894  movement-4fe03c73-dfa4-449c-bb95-7f6ce06bd9e3  Location     254478.044
#
#        originNorthing  destinationEasting  destinationNorthing
# 0          667190.412          254507.045           667288.414
# 1          667190.412          254507.045           667288.414
# 2          667190.412          254507.045           667288.414
# 3          667190.412          254507.045           667288.414
# 4          667190.412          254507.045           667288.414
# ...               ...                 ...                  ...
# 78890      667190.412          254507.045           667288.414
# 78891      667190.412          254507.045           667288.414
# 78892      667190.412          254507.045           667288.414
# 78893      667190.412          254507.045           667288.414
# 78894      667190.412          254507.045           667288.414
#
# [78895 rows x 19 columns]

# %% [markdown]
# ### 2.1 Create a df with full timestamp

# %%
from datetime import datetime, timedelta

def get_time_string_list(start,end,interval):
    start = datetime.strptime(start, "%Y-%m-%d %H:%M:%S")
    end = datetime.strptime(end, "%Y-%m-%d %H:%M:%S")
    now = start
    string_list = []
    while now <= end:
        now += timedelta(minutes=15)
        string_list.append(now.strftime("%Y-%m-%d %H:%M:%S"))
    return string_list

time_list = get_time_string_list("2019-08-04 23:45:00","2021-12-12 23:30:00",15)

# %% [markdown]
# ### 2.2 Drop the timestamp from 2019-10-17 to 2019-11-19

# %%
allTime = pd.DataFrame(time_list, columns=['timeStamp'])

errorTime_range = pd.date_range(date(2019, 10, 17), date(2019, 11, 19)).tolist()
errorTime_list = [date_obj.strftime('%Y-%m-%d') for date_obj in timestamp_range]

for i in errorTime_list:
    allTime = allTime[~allTime["timeStamp"].str.contains(i)]

usefulTime = allTime.sort_values(['timeStamp']).reset_index(drop=True)

# %%
usefulTime
# Out:
#                  timeStamp
# 0      2019-08-05 00:00:00
# 1      2019-08-05 00:15:00
# 2      2019-08-05 00:30:00
# 3      2019-08-05 00:45:00
# 4      2019-08-05 01:00:00
# ...                    ...
# 79387  2021-12-12 22:45:00
# 79388  2021-12-12 23:00:00
# 79389  2021-12-12 23:15:00
# 79390  2021-12-12 23:30:00
# 79391  2021-12-12 23:45:00
#
# [79392 rows x 1 columns]

# %% [markdown]
# ### 2.3 Merge the traffic flow to the usefulTime

# %%
# recover the each timestamp to int
data['timeStamp'] = data['lastUpdate'].str.split('.').str[0].str.replace('T',' ')
data['time'] = data['timeStamp'].str.split(' ').str[-1].str.split(':',1).str[-1].str.replace(':','.')
data['time'] = pd.to_numeric(data['time'])
for i in range(len(data)):
    if 0 <= data['time'][i] < 15:
        data['time'][i] = 0
    elif 15 <= data['time'][i] < 30:
        data['time'][i] = 15
    elif 30 <= data['time'][i] < 45:
        data['time'][i] = 30
    elif 45 <= data['time'][i] < 60:
        data['time'][i] = 45

data['time'] = data['time'].astype(str).str.replace('.',':').str.zfill(4).str.ljust(5, '0')
data['timeStamp'] = data['timeStamp'].str[:-5] + data['time'].str[-5:]
# Out:
# E:\program\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# 78894              0  612fadda-7b80-40c6-89ee-67907a4f90bd
#
#                                                   id      type originEasting  \
# 0      movement-46b48ed7-645c-493b-bee6-542365cc7343  Location    254478.044
# 1      movement-489e103c-9f65-4ebc-9e64-43f0cec9a692  Location    254478.044
# 2      movement-a2de2c40-7aa2-40af-bede-76b12a03e148  Location    254478.044
# 3      movement-fcd293dc-b281-486f-9ca3-ef2ee84506a9  Location    254478.044
# 4      movement-5c571e65-c076-490b-bfeb-f82bd5982350  Location    254478.044
# ...                                              ...       ...           ...
# 78890  movement-1c2c1857-1f46-48cf-ad36-b75c01472265  Location    254478.044
# 78891  movement-d4d6ce34-b0a4-4481-ab00-5a4b8d5b29c9  Location    254478.044
# 78892  movement-06777ded-9a05-4101-bd8c-e0e345e069a3  Location    254478.044
# 78893  movement-4081cfcb-a3d4-4674-a84f-caffac24b352  Location    254478.044
# 78894  movement-4fe03c73-dfa4-449c-bb95-7f6ce06bd9e3  Location    254478.044
#
#        originNorthing  destinationEasting  destinationNorthing  \
# 0          667190.412          254507.045           667288.414
# 1          667190.412          254507.045           667288.414
# 2          667190.412          254507.045           667288.414
# 3          667190.412          254507.045           667288.414
# 4          667190.412          254507.045           667288.414
# ...               ...                 ...                  ...
# 78890      667190.412          254507.045           667288.414
# 78891      667190.412          254507.045           667288.414
# 78892      667190.412          254507.045           667288.414
# 78893      667190.412          254507.045           667288.414
# 78894      667190.412          254507.045           667288.414
#
#                  timeStamp   time
# 0      2019-08-05 00:00:00  00:00
# 1      2019-08-05 00:15:00  15:00
# 2      2019-08-05 00:30:00  30:00
# 3      2019-08-05 00:45:00  45:00
# 4      2019-08-05 01:00:00  00:00
# ...                    ...    ...
# 78890  2021-12-12 22:45:00  45:00
# 78891  2021-12-12 23:00:00  00:00
# 78892  2021-12-12 23:15:00  15:00
# 78893  2021-12-12 23:30:00  30:00
# 78894  2021-12-12 23:45:00  45:00
#
# [78895 rows x 21 columns]

# %%
#merge the data
pd.merge(usefulTime, data[['timeStamp', 'flow']], how="left", on="timeStamp")
# Out:
#                  timeStamp  flow
# 0      2019-08-05 00:00:00   3.0
# 1      2019-08-05 00:15:00   4.0
# 2      2019-08-05 00:30:00   3.0
# 3      2019-08-05 00:45:00   3.0
# 4      2019-08-05 01:00:00   2.0
# ...                    ...   ...
# 79403  2021-12-12 22:45:00  40.0
# 79404  2021-12-12 23:00:00  48.0
# 79405  2021-12-12 23:15:00  53.0
# 79406  2021-12-12 23:30:00  35.0
# 79407  2021-12-12 23:45:00  44.0
#
# [79408 rows x 2 columns]

# %%
data = pd.read_csv('../../../Data/Data processing/20211028_SCOOT_Data/JupyterNotebook_CSV/20211213_SCOOT_data/GB0701_D&2019_08_05-2021_12_12.csv')

# %%
data
# Out:
#                          lastUpdate            timestamp siteSiteid  count  \
# 0      2020-07-11T21:30:00.3252876Z  2020-07-11T22:25:11   GB0701_D      1
# 1      2020-07-11T21:45:00.3189112Z  2020-07-11T22:40:11   GB0701_D      1
# 2       2020-07-11T22:00:00.855971Z  2020-07-11T22:55:11   GB0701_D      1
# 3      2020-07-11T22:15:00.7965565Z  2020-07-11T23:10:11   GB0701_D      1
# 4      2020-07-11T22:30:00.9482113Z  2020-07-11T23:25:10   GB0701_D      1
# ...                             ...                  ...        ...    ...
# 78902  2020-07-11T20:15:01.3472426Z  2020-07-11T21:10:11   GB0701_D      1
# 78903  2020-07-11T20:30:01.0432177Z  2020-07-11T21:25:10   GB0701_D      1
# 78904  2020-07-11T20:45:00.3169178Z  2020-07-11T21:40:11   GB0701_D      1
# 78905  2020-07-11T21:00:01.0538151Z  2020-07-11T21:55:10   GB0701_D      1
# 78906  2020-07-11T21:15:00.7174363Z  2020-07-11T22:10:10   GB0701_D      1
#
#                                originDescription  originLat  originLong  \
# 0      Eglinton Street southbound to Cook Street  55.851598    -4.25928
# 1      Eglinton Street southbound to Cook Street  55.851598    -4.25928
# 2      Eglinton Street southbound to Cook Street  55.851598    -4.25928
# 3      Eglinton Street southbound to Cook Street  55.851598    -4.25928
# 4      Eglinton Street southbound to Cook Street  55.851598    -4.25928
# ...                                          ...        ...         ...
# 78902  Eglinton Street southbound to Cook Street  55.851598    -4.25928
# 78903  Eglinton Street southbound to Cook Street  55.851598    -4.25928
# 78904  Eglinton Street southbound to Cook Street  55.851598    -4.25928
# 78905  Eglinton Street southbound to Cook Street  55.851598    -4.25928
# 78906  Eglinton Street southbound to Cook Street  55.851598    -4.25928
#
#                           destinationDescription  destinationLat  \
# 0      Eglinton Street southbound to Cook Street       55.851621
# 1      Eglinton Street southbound to Cook Street       55.851621
# 2      Eglinton Street southbound to Cook Street       55.851621
# 3      Eglinton Street southbound to Cook Street       55.851621
# 4      Eglinton Street southbound to Cook Street       55.851621
# ...                                          ...             ...
# 78902  Eglinton Street southbound to Cook Street       55.851621
# 78903  Eglinton Street southbound to Cook Street       55.851621
# 78904  Eglinton Street southbound to Cook Street       55.851621
# 78905  Eglinton Street southbound to Cook Street       55.851621
# 78906  Eglinton Street southbound to Cook Street       55.851621
#
#        destinationLong  flow  concentration  \
# 0            -4.259473    44              0
# 1            -4.259473    40              0
# 2            -4.259473    40              0
# 3            -4.259473    35              0
# 4            -4.259473    40              0
# ...                ...   ...            ...
# 78902        -4.259473    44              0
# 78903        -4.259473    44              0
# 78904        -4.259473    40              0
# 78905        -4.259473    40              0
# 78906        -4.259473    40              0
#
#                             batchIdentifier  \
# 0      015ce8a6-0239-4525-9948-de4a66be79fe
# 1      aa437b37-d2e0-447e-81ab-259b1b2aea65
# 2      8ece1d39-43cd-4bcf-90aa-f5ec6c14142a
# 3      3d1d8fa8-2e37-4b0d-b60e-c21f4a7ecd4a
# 4      8de37019-719f-4582-a0ae-0b70a91b548c
# ...                                     ...
# 78902  a39ce8b3-2bba-4bd7-885c-a46ac2762e45
# 78903  7d4bf994-64b0-4561-8995-5c662c9f0e04
# 78904  db8249f6-9a54-4a20-8eea-752300c91864
# 78905  73cd7a6d-2671-481e-86ef-f30a1b5988a1
# 78906  c8ba1a4c-61d1-4542-934e-242b5db886a5
#
#                                                   id      type  originEasting  \
# 0      movement-753df70f-473e-4a55-9df8-1245c418f1e6  Location     258661.087
# 1      movement-b1ee1be3-088f-4f1b-af4b-65d412eb3533  Location     258661.087
# 2      movement-95ab86b9-b069-4ee6-ba1c-c4a304d4e34d  Location     258661.087
# 3      movement-ac233a0c-0550-4412-b2c7-c8cbd663098f  Location     258661.087
# 4      movement-5496d0fc-d2b1-4461-9342-655e6dc5cde1  Location     258661.087
# ...                                              ...       ...            ...
# 78902  movement-3e110fef-4a4f-418c-a625-10caeda68c06  Location     258661.087
# 78903  movement-e59da4ad-a47d-4b3b-bd03-c66c4e59aedf  Location     258661.087
# 78904  movement-06c68a40-2178-43d7-9002-4d4995908481  Location     258661.087
# 78905  movement-c6ca82df-96a8-4cae-a89f-7508f8b6ab54  Location     258661.087
# 78906  movement-749cb485-4c90-4c59-a6a3-ab4c4cba83d8  Location     258661.087
#
#        originNorthing  destinationEasting  destinationNorthing
# 0          664353.327          258649.087           664356.328
# 1          664353.327          258649.087           664356.328
# 2          664353.327          258649.087           664356.328
# 3          664353.327          258649.087           664356.328
# 4          664353.327          258649.087           664356.328
# ...               ...                 ...                  ...
# 78902      664353.327          258649.087           664356.328
# 78903      664353.327          258649.087           664356.328
# 78904      664353.327          258649.087           664356.328
# 78905      664353.327          258649.087           664356.328
# 78906      664353.327          258649.087           664356.328
#
# [78907 rows x 19 columns]

# %%
from datetime import date
print(len(pd.date_range(date(2019, 8, 5), date(2019, 10, 16))))
len(pd.date_range(date(2019, 11, 20), date(2021, 12, 12)))
# Out:
# 73
# 754

# %%
stats = pd.read_csv('../../../Data/Data processing/20211028_SCOOT_Data/JupyterNotebook_CSV/SCOOT_data_statistic/all_sites_statistic_detailed.csv')

# %%
sites = list(detectors.siteId)
all_sites = list(stats.siteId.unique())
error_sites = list(set(all_sites) - set(sites))
len(error_sites)
# Out:
# 444

# %%
for site in error_sites:
    stats.drop(stats[stats['siteId'] == site].index, inplace=True)
len(stats.siteId.unique())
# Out:
# 530

# %% [markdown]
# ### Get the stats of error dates

# %%
error_dates = list(stats.loc[stats['errorPercentage/Day(%)']>10,'errorDate'].unique())
error_dates.sort()
#get the error dates & the correspounding num of sites 
for i in error_dates:
    print(len(stats.loc[stats['errorPercentage(%)']<1].loc[stats['errorDate'] == i]),i)
#get the error dates & the correspounding errorPercentage/Day
stats.loc[stats['errorPercentage(%)']<1].loc[stats['errorPercentage/Day(%)']>10][['errorDate', 'errorPercentage/Day(%)']].sort_values(by=['errorPercentage/Day(%)','errorDate']).drop_duplicates(keep='first').sort_values(by=['errorPercentage/Day(%)','errorDate']).reset_index(drop=True)
# Out:
# 530 2020-03-12
# 530 2020-05-05
# 530 2020-06-24
# 530 2020-09-25
# 530 2020-10-30
# 530 2020-11-17
# 90 2020-12-02
# 530 2020-12-05
# 530 2021-02-23
# 530 2021-03-02
# 530 2021-05-18
# 530 2021-10-13
#      errorDate  errorPercentage/Day(%)
# 0   2020-12-05               10.416667
# 1   2021-02-23               10.416667
# 2   2020-12-02               11.111111
# 3   2021-03-02               11.458333
# 4   2020-12-02               15.789474
# 5   2020-12-02               16.666667
# 6   2020-10-30               17.708333
# 7   2020-03-12               19.791667
# 8   2020-03-12               20.833333
# 9   2020-05-05               31.250000
# 10  2020-05-05               31.958763
# 11  2020-05-05               32.291667
# 12  2020-06-24               32.592593
# 13  2020-05-05               32.989691
# 14  2020-11-17               37.500000
# 15  2020-11-17               38.144330
# 16  2021-10-13               40.625000
# 17  2021-10-13               41.666667
# 18  2021-10-13               42.708333
# 19  2020-09-25               47.916667
# 20  2021-05-18               60.377358
# 21  2021-05-18               61.635220
