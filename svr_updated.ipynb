# %%
import numpy as np
import pandas as pd
from sklearn.svm import SVR
from itertools import product
from sklearn.preprocessing import MinMaxScaler
from sklearn.multioutput import MultiOutputRegressor
from sklearn.metrics import mean_absolute_percentage_error, mean_absolute_error, mean_squared_error

# %%
traffic_data = pd.read_csv('GD030A_S.csv')

# %% [markdown]
# ## 1. Recover timestamp

# %%
# Define the recover_timestamp function
def recover_timestamp(data):
    # Combine 'date' and 'time' to form a datetime column
    data['datetime'] = pd.to_datetime(data['date'] + ' ' + data['time'].astype(str) + ':00', format='%Y-%m-%d %H:%M')

    # Set 'datetime' as index
    data = data.set_index('datetime')

    # Create a complete range of timestamps with hourly frequency
    full_time_range = pd.date_range(start=data.index.min(), end=data.index.max(), freq='H')

    # Reindex the data to include all timestamps, filling missing rows with NaN
    data_full = data.reindex(full_time_range)

    return data_full

# %%
# Apply the recover_timestamp function to recover the full time series
traffic_full = recover_timestamp(traffic_data)
traffic_full
# Out:
#                            date  time   flow
# 2019-10-01 00:00:00  2019-10-01   0.0   15.0
# 2019-10-01 01:00:00  2019-10-01   1.0    9.0
# 2019-10-01 02:00:00  2019-10-01   2.0    9.0
# 2019-10-01 03:00:00  2019-10-01   3.0    7.0
# 2019-10-01 04:00:00  2019-10-01   4.0    9.0
# ...                         ...   ...    ...
# 2023-09-30 19:00:00  2023-09-30  19.0  129.0
# 2023-09-30 20:00:00  2023-09-30  20.0  119.0
# 2023-09-30 21:00:00  2023-09-30  21.0  106.0
# 2023-09-30 22:00:00  2023-09-30  22.0   88.0
# 2023-09-30 23:00:00  2023-09-30  23.0   88.0
#
# [35064 rows x 3 columns]

# %% [markdown]
# ## 2. Train, validate, test data split

# %%
# train_set = traffic_full[:'2022-02-28 23:00:00']
# valid_set = traffic_full['2022-03-01 00:00:00':'2022-12-31 23:00:00']
# test_set = traffic_full['2023-01-01 00:00:00':]
train_set = traffic_full['2022-06-03 00:00:00':'2023-03-31 23:00:00']
valid_set = traffic_full['2023-04-01 00:00:00':'2023-06-30 23:00:00']
test_set = traffic_full['2023-07-01 00:00:00':]
print('Proportion of train_set : {:.4f}'.format(len(train_set)/len(traffic_full['2022-06-03 00:00:00':])))
print('Proportion of valid_set : {:.4f}'.format(len(valid_set)/len(traffic_full['2022-06-03 00:00:00':])))
print('Proportion of test_set : {:.4f}'.format(len(test_set)/len(traffic_full['2022-06-03 00:00:00':])))
# Out:
# Proportion of train_set : 0.6227
# Proportion of valid_set : 0.1876
# Proportion of test_set : 0.1897

# %%
print(train_set.isnull().sum(), len(train_set))
print(valid_set.isnull().sum(),len(valid_set))
print(test_set.isnull().sum(),len(test_set))
# Out:
# date    16
# time    16
# flow    16
# dtype: int64 7248
# date    61
# time    61
# flow    61
# dtype: int64 2184
# date    342
# time    342
# flow    342
# dtype: int64 2208

# %% [markdown]
# ## 3. Normalise the data

# %%
# Initialize the scaler
scaler = MinMaxScaler()

# Fit the scaler on the training data's 'flow' feature
scaler.fit(train_set[['flow']])

# Transform the 'flow' feature in all datasets
train_set.loc[:, 'flow_scaled'] = scaler.transform(train_set[['flow']])
valid_set.loc[:, 'flow_scaled'] = scaler.transform(valid_set[['flow']])
test_set.loc[:, 'flow_scaled'] = scaler.transform(test_set[['flow']])
# Out:
# /tmp/ipykernel_2454252/1100395100.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_set.loc[:, 'flow_scaled'] = scaler.transform(train_set[['flow']])
# /tmp/ipykernel_2454252/1100395100.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_set.loc[:, 'flow_scaled'] = scaler.transform(valid_set[['flow']])
# /tmp/ipykernel_2454252/1100395100.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_set.loc[:, 'flow_scaled'] = scaler.transform(test_set[['flow']])

# %% [markdown]
# ## 4. Split the data into X and y

# %%
def create_sequences(data, input_length, forecast_horizon):
    """
    Creates input-output sequences for time series data for SVR (MultiOutputRegressor).
    
    Parameters:
    - data: pandas DataFrame containing the data. Must include the 'flow_scaled' column.
    - input_length: int, number of past time steps to include in each input sequence.
    - forecast_horizon: int, number of future steps to predict.
    
    Returns:
    - X: numpy array of shape (num_valid_samples, input_length)
    - y: numpy array of shape (num_valid_samples, forecast_horizon)
    """
    X, y = [], []
    
    # Iterate through the data to create sequences
    for i in range(input_length, len(data) - forecast_horizon + 1):
        # Extract the input sequence (flattened to a 1D array)
        X_seq = data.iloc[i - input_length:i]['flow_scaled'].values
        
        # Extract the target sequence (future steps)
        y_seq = data.iloc[i:i + forecast_horizon]['flow_scaled'].values
        
        # Check for NaN values in the input sequence and target sequence
        if not np.isnan(X_seq).any() and not np.isnan(y_seq).any():
            X.append(X_seq)
            y.append(y_seq)
        else:
            # Optionally, log or count the skipped sequences
            pass  # Simply skip sequences with NaNs
        
    # Convert to numpy arrays
    X = np.array(X)  # Shape: (num_valid_samples, input_length)
    y = np.array(y)  # Shape: (num_valid_samples, forecast_horizon)
    
    return X, y

# %% [markdown]
# ## 5. Create X and y

# %% [markdown]
# #### We will use
# * the last 24*N steps
#
# *  to forecast current (0 step) and 5 steps ahead

# %%
# Define Input Sequence Lengths
input_lengths = [24 * i for i in range(1, 22)]  # [24, 48, ..., 168]

# %%
from collections import defaultdict
data_dict = defaultdict(dict)

for length in input_lengths:
    print(f"Processing input length: {length}")
    
    # Create sequences with forecast_horizon=6
    X_train, y_train = create_sequences(train_set, length, forecast_horizon=6)
    X_val, y_val = create_sequences(valid_set, length, forecast_horizon=6)
    X_test, y_test = create_sequences(test_set, length, forecast_horizon=6)
    
    # Store in the dictionary
    data_dict[length]['X_train'] = X_train
    data_dict[length]['y_train'] = y_train
    data_dict[length]['X_val'] = X_val
    data_dict[length]['y_val'] = y_val
    data_dict[length]['X_test'] = X_test
    data_dict[length]['y_test'] = y_test
    
    # Print shapes and ensure no NaNs
    print(f"  X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
    print(f"  X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
    print(f"  X_test shape: {X_test.shape}, y_test shape: {y_test.shape}\n")
# Out:
# Processing input length: 24
#   X_train shape: (7145, 24), y_train shape: (7145, 6)
#   X_val shape: (2007, 24), y_val shape: (2007, 6)
#   X_test shape: (1719, 24), y_test shape: (1719, 6)
#
# Processing input length: 48
#   X_train shape: (7073, 48), y_train shape: (7073, 6)
#   X_val shape: (1911, 48), y_val shape: (1911, 6)
#   X_test shape: (1604, 48), y_test shape: (1604, 6)
#
# Processing input length: 72
#   X_train shape: (7001, 72), y_train shape: (7001, 6)
#   X_val shape: (1815, 72), y_val shape: (1815, 6)
#   X_test shape: (1508, 72), y_test shape: (1508, 6)
#
# Processing input length: 96
#   X_train shape: (6929, 96), y_train shape: (6929, 6)
#   X_val shape: (1719, 96), y_val shape: (1719, 6)
#   X_test shape: (1412, 96), y_test shape: (1412, 6)
#
# Processing input length: 120
#   X_train shape: (6857, 120), y_train shape: (6857, 6)
#   X_val shape: (1623, 120), y_val shape: (1623, 6)
#   X_test shape: (1316, 120), y_test shape: (1316, 6)
#
# Processing input length: 144
#   X_train shape: (6785, 144), y_train shape: (6785, 6)
#   X_val shape: (1527, 144), y_val shape: (1527, 6)
#   X_test shape: (1220, 144), y_test shape: (1220, 6)
#
# Processing input length: 168
#   X_train shape: (6713, 168), y_train shape: (6713, 6)
#   X_val shape: (1431, 168), y_val shape: (1431, 6)
#   X_test shape: (1124, 168), y_test shape: (1124, 6)
#
# Processing input length: 192
#   X_train shape: (6641, 192), y_train shape: (6641, 6)
#   X_val shape: (1335, 192), y_val shape: (1335, 6)
#   X_test shape: (1028, 192), y_test shape: (1028, 6)
#
# Processing input length: 216
#   X_train shape: (6569, 216), y_train shape: (6569, 6)
#   X_val shape: (1239, 216), y_val shape: (1239, 6)
#   X_test shape: (932, 216), y_test shape: (932, 6)
#
# Processing input length: 240
#   X_train shape: (6497, 240), y_train shape: (6497, 6)
#   X_val shape: (1143, 240), y_val shape: (1143, 6)
#   X_test shape: (836, 240), y_test shape: (836, 6)
#
# Processing input length: 264
#   X_train shape: (6425, 264), y_train shape: (6425, 6)
#   X_val shape: (1047, 264), y_val shape: (1047, 6)
#   X_test shape: (740, 264), y_test shape: (740, 6)
#
# Processing input length: 288
#   X_train shape: (6353, 288), y_train shape: (6353, 6)
#   X_val shape: (963, 288), y_val shape: (963, 6)
#   X_test shape: (660, 288), y_test shape: (660, 6)
#
# Processing input length: 312
#   X_train shape: (6281, 312), y_train shape: (6281, 6)
#   X_val shape: (891, 312), y_val shape: (891, 6)
#   X_test shape: (588, 312), y_test shape: (588, 6)
#
# Processing input length: 336
#   X_train shape: (6209, 336), y_train shape: (6209, 6)
#   X_val shape: (819, 336), y_val shape: (819, 6)
#   X_test shape: (516, 336), y_test shape: (516, 6)
#
# Processing input length: 360
#   X_train shape: (6137, 360), y_train shape: (6137, 6)
#   X_val shape: (747, 360), y_val shape: (747, 6)
#   X_test shape: (444, 360), y_test shape: (444, 6)
#
# Processing input length: 384
#   X_train shape: (6065, 384), y_train shape: (6065, 6)
#   X_val shape: (675, 384), y_val shape: (675, 6)
#   X_test shape: (390, 384), y_test shape: (390, 6)
#
# Processing input length: 408
#   X_train shape: (5993, 408), y_train shape: (5993, 6)
#   X_val shape: (603, 408), y_val shape: (603, 6)
#   X_test shape: (342, 408), y_test shape: (342, 6)
#
# Processing input length: 432
#   X_train shape: (5921, 432), y_train shape: (5921, 6)
#   X_val shape: (531, 432), y_val shape: (531, 6)
#   X_test shape: (311, 432), y_test shape: (311, 6)
#
# Processing input length: 456
#   X_train shape: (5849, 456), y_train shape: (5849, 6)
#   X_val shape: (459, 456), y_val shape: (459, 6)
#   X_test shape: (287, 456), y_test shape: (287, 6)
#
# Processing input length: 480
#   X_train shape: (5777, 480), y_train shape: (5777, 6)
#   X_val shape: (387, 480), y_val shape: (387, 6)
#   X_test shape: (263, 480), y_test shape: (263, 6)
#
# Processing input length: 504
#   X_train shape: (5705, 504), y_train shape: (5705, 6)
#   X_val shape: (333, 504), y_val shape: (333, 6)
#   X_test shape: (239, 504), y_test shape: (239, 6)

# %% [markdown]
# ## 6. Build SVR model

# %%
def build_svr_model(hyperparams):
    if hyperparams['kernel'] == 'poly':  # Ensure degree is used for 'poly' kernel
        model = MultiOutputRegressor(SVR(C=hyperparams['C'], epsilon=hyperparams['epsilon'], 
                                             kernel=hyperparams['kernel'], gamma=hyperparams['gamma'], 
                                             degree=hyperparams['degree']))
    elif hyperparams['kernel'] == 'linear':  # No need for gamma or degree for 'linear'
        model = MultiOutputRegressor(SVR(C=hyperparams['C'], epsilon=hyperparams['epsilon'], 
                                             kernel=hyperparams['kernel']))
    else: # For RBF, sigmoid, etc., gamma is necessary
        model = MultiOutputRegressor(SVR(C=hyperparams['C'], epsilon=hyperparams['epsilon'], 
                                             kernel=hyperparams['kernel'], gamma=hyperparams['gamma']))
    return model

# %% [markdown]
# ## 7. Define the hyperparameter grid

# %%
from itertools import product

# Define hyperparameter grid with conditions on kernel types
hyperparameter_grid = {               
    'C': [1, 10, 100],              # Regularization parameter
    'epsilon': [0.01, 0.1, 0.2],    # Epsilon parameter
    'gamma': ['scale', 'auto', 0.001, 0.01, 0.1, 1],  # Kernel coefficient for RBF, poly, and sigmoid
    'kernel': ['linear', 'rbf', 'poly', 'sigmoid'],  # Kernels to try
    'degree': [2, 3, 4]             # Degree of the polynomial kernel (only for 'poly')
}

# Generate all combinations, respecting kernel-specific constraints
all_combinations = []

# Iterate over each kernel type and create the combinations accordingly
for kernel in hyperparameter_grid['kernel']:
    if kernel == 'linear':
        # For linear kernel, do not include 'gamma' and 'degree'
        for C, epsilon in product(hyperparameter_grid['C'], hyperparameter_grid['epsilon']):
            all_combinations.append((C, epsilon, None, kernel, None))  # No gamma, no degree
    elif kernel == 'poly':
        # For poly kernel, include 'gamma' and 'degree'
        for C, epsilon, gamma, degree in product(
            hyperparameter_grid['C'], 
            hyperparameter_grid['epsilon'], 
            hyperparameter_grid['gamma'], 
            hyperparameter_grid['degree']
        ):
            all_combinations.append((C, epsilon, gamma, kernel, degree))  # Include gamma and degree
    else:
        # For other kernels (rbf, sigmoid), include 'gamma' but not 'degree'
        for C, epsilon, gamma in product(
            hyperparameter_grid['C'], 
            hyperparameter_grid['epsilon'], 
            hyperparameter_grid['gamma']
        ):
            all_combinations.append((C, epsilon, gamma, kernel, None))  # No degree

# Display the resulting combinations
print(f"Total combinations: {len(all_combinations)}")
print(all_combinations[:10])  # Display the first 10 combinations
# Out:
# Total combinations: 279
# [(1, 0.01, None, 'linear', None), (1, 0.1, None, 'linear', None), (1, 0.2, None, 'linear', None), (10, 0.01, None, 'linear', None), (10, 0.1, None, 'linear', None), (10, 0.2, None, 'linear', None), (100, 0.01, None, 'linear', None), (100, 0.1, None, 'linear', None), (100, 0.2, None, 'linear', None), (1, 0.01, 'scale', 'rbf', None)]

# %% [markdown]
# ## 8. Defining manual grid search

# %%
import logging

logging.basicConfig(
    level=logging.INFO,  # Set the logging level to INFO
    format='%(asctime)s - %(message)s',  # Customize the log message format
    handlers=[
        logging.FileHandler('svr_updated.log'),  # Log messages to 'output.log'
        logging.StreamHandler()             # Also output to console/notebook
    ]
)

# %%
results = []

# Loop over each input length
for length in input_lengths:
    logging.info(f"Starting grid search for input length: {length}")
    
    X_train = data_dict[length]['X_train']
    y_train = data_dict[length]['y_train']
    X_val = data_dict[length]['X_val']
    y_val = data_dict[length]['y_val']
    
    best_mse = float('inf')
    best_params = {}
    best_model = None
    
    # Iterate through all combinations of hyperparameters
    for idx, combination in enumerate(all_combinations):
        hyperparams = {
            'C': combination[0],
            'epsilon': combination[1],
            'gamma': combination[2],
            'kernel': combination[3],
            'degree': combination[4]
        }
        
        logging.info(f"  Evaluating combination {idx + 1}/{len(all_combinations)}: {hyperparams}")

        # build the svr model
        model = build_svr_model(hyperparams)
        # train the model
        model.fit(X_train, y_train)
        # Validate the model on the validation set
        y_val_pred = model.predict(X_val)
        
        # Calculate MSE on the validation set
        current_best_mse = mean_squared_error(y_val, y_val_pred)
        logging.info(f"Validation MSE: {current_best_mse:.5f}")
        
        # If this combination gives a better validation MSE, update the best model
        if current_best_mse < best_mse:
            best_mse = current_best_mse
            best_params = hyperparams.copy()
            best_model = model
    
    # Store the best results
    results.append({
        'Input_Length': length,
        'Best_MSE': best_mse,
        'Best_Hyperparameters': best_params
    })
    
    logging.info(f"Completed grid search for input length: {length}")
    logging.info(f"  Best Validation MSE: {best_mse:.5f}")
    logging.info(f"  Best Hyperparameters: {best_params}\n")
# Out:
# 2025-01-15 07:59:50,167 - Starting grid search for input length: 24
# 2025-01-15 07:59:50,170 -   Evaluating combination 1/279: {'C': 1, 'epsilon': 0.01, 'gamma': None, 'kernel': 'linear', 'degree': None}
# 2025-01-15 08:00:05,301 - Validation MSE: 0.00502
# 2025-01-15 08:00:05,302 -   Evaluating combination 2/279: {'C': 1, 'epsilon': 0.1, 'gamma': None, 'kernel': 'linear', 'degree': None}
# 2025-01-15 08:00:08,106 - Validation MSE: 0.00546
# 2025-01-15 08:00:08,108 -   Evaluating combination 3/279: {'C': 1, 'epsilon': 0.2, 'gamma': None, 'kernel': 'linear', 'degree': None}
# 2025-01-15 08:00:08,991 - Validation MSE: 0.00996
# 2025-01-15 08:00:08,993 -   Evaluating combination 4/279: {'C': 10, 'epsilon': 0.01, 'gamma': None, 'kernel': 'linear', 'degree': None}
# 2025-01-15 08:00:57,896 - Validation MSE: 0.00502
# 2025-01-15 08:00:57,897 -   Evaluating combination 5/279: {'C': 10, 'epsilon': 0.1, 'gamma': None, 'kernel': 'linear', 'degree': None}
# 2025-01-15 08:01:05,912 - Validation MSE: 0.00546
# 2025-01-15 08:01:05,913 -   Evaluating combination 6/279: {'C': 10, 'epsilon': 0.2, 'gamma': None, 'kernel': 'linear', 'degree': None}
# 2025-01-15 08:01:07,860 - Validation MSE: 0.00994
# 2025-01-15 08:01:07,861 -   Evaluating combination 7/279: {'C': 100, 'epsilon': 0.01, 'gamma': None, 'kernel': 'linear', 'degree': None}
# 2025-01-15 08:06:06,657 - Validation MSE: 0.00502
# 2025-01-15 08:06:06,659 -   Evaluating combination 8/279: {'C': 100, 'epsilon': 0.1, 'gamma': None, 'kernel': 'linear', 'degree': None}
# 2025-01-15 08:06:45,951 - Validation MSE: 0.00546
# 2025-01-15 08:06:45,952 -   Evaluating combination 9/279: {'C': 100, 'epsilon': 0.2, 'gamma': None, 'kernel': 'linear', 'degree': None}
# 2025-01-15 08:06:54,198 - Validation MSE: 0.00995
# 2025-01-15 08:06:54,199 -   Evaluating combination 10/279: {'C': 1, 'epsilon': 0.01, 'gamma': 'scale', 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:07:16,195 - Validation MSE: 0.00471
# 2025-01-15 08:07:16,196 -   Evaluating combination 11/279: {'C': 1, 'epsilon': 0.01, 'gamma': 'auto', 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:07:28,178 - Validation MSE: 0.00458
# 2025-01-15 08:07:28,179 -   Evaluating combination 12/279: {'C': 1, 'epsilon': 0.01, 'gamma': 0.001, 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:07:40,663 - Validation MSE: 0.00527
# 2025-01-15 08:07:40,665 -   Evaluating combination 13/279: {'C': 1, 'epsilon': 0.01, 'gamma': 0.01, 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:07:53,152 - Validation MSE: 0.00487
# 2025-01-15 08:07:53,154 -   Evaluating combination 14/279: {'C': 1, 'epsilon': 0.01, 'gamma': 0.1, 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:08:06,363 - Validation MSE: 0.00447
# 2025-01-15 08:08:06,365 -   Evaluating combination 15/279: {'C': 1, 'epsilon': 0.01, 'gamma': 1, 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:08:24,178 - Validation MSE: 0.00442
# 2025-01-15 08:08:24,179 -   Evaluating combination 16/279: {'C': 1, 'epsilon': 0.1, 'gamma': 'scale', 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:08:27,016 - Validation MSE: 0.00549
# 2025-01-15 08:08:27,018 -   Evaluating combination 17/279: {'C': 1, 'epsilon': 0.1, 'gamma': 'auto', 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:08:29,291 - Validation MSE: 0.00512
# 2025-01-15 08:08:29,293 -   Evaluating combination 18/279: {'C': 1, 'epsilon': 0.1, 'gamma': 0.001, 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:08:32,001 - Validation MSE: 0.00615
# 2025-01-15 08:08:32,003 -   Evaluating combination 19/279: {'C': 1, 'epsilon': 0.1, 'gamma': 0.01, 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:08:34,340 - Validation MSE: 0.00550
# 2025-01-15 08:08:34,341 -   Evaluating combination 20/279: {'C': 1, 'epsilon': 0.1, 'gamma': 0.1, 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:08:36,565 - Validation MSE: 0.00501
# 2025-01-15 08:08:36,566 -   Evaluating combination 21/279: {'C': 1, 'epsilon': 0.1, 'gamma': 1, 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:08:39,231 - Validation MSE: 0.00515
# 2025-01-15 08:08:39,232 -   Evaluating combination 22/279: {'C': 1, 'epsilon': 0.2, 'gamma': 'scale', 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:08:40,252 - Validation MSE: 0.01274
# 2025-01-15 08:08:40,253 -   Evaluating combination 23/279: {'C': 1, 'epsilon': 0.2, 'gamma': 'auto', 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:08:40,854 - Validation MSE: 0.01052
# 2025-01-15 08:08:40,856 -   Evaluating combination 24/279: {'C': 1, 'epsilon': 0.2, 'gamma': 0.001, 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:08:41,661 - Validation MSE: 0.01277
# 2025-01-15 08:08:41,663 -   Evaluating combination 25/279: {'C': 1, 'epsilon': 0.2, 'gamma': 0.01, 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:08:42,296 - Validation MSE: 0.01123
# 2025-01-15 08:08:42,298 -   Evaluating combination 26/279: {'C': 1, 'epsilon': 0.2, 'gamma': 0.1, 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:08:43,013 - Validation MSE: 0.01053
# 2025-01-15 08:08:43,014 -   Evaluating combination 27/279: {'C': 1, 'epsilon': 0.2, 'gamma': 1, 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:08:43,935 - Validation MSE: 0.01205
# 2025-01-15 08:08:43,937 -   Evaluating combination 28/279: {'C': 10, 'epsilon': 0.01, 'gamma': 'scale', 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:10:21,402 - Validation MSE: 0.00620
# 2025-01-15 08:10:21,403 -   Evaluating combination 29/279: {'C': 10, 'epsilon': 0.01, 'gamma': 'auto', 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:10:36,830 - Validation MSE: 0.00446
# 2025-01-15 08:10:36,831 -   Evaluating combination 30/279: {'C': 10, 'epsilon': 0.01, 'gamma': 0.001, 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:10:48,740 - Validation MSE: 0.00501
# 2025-01-15 08:10:48,741 -   Evaluating combination 31/279: {'C': 10, 'epsilon': 0.01, 'gamma': 0.01, 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:11:01,605 - Validation MSE: 0.00462
# 2025-01-15 08:11:01,607 -   Evaluating combination 32/279: {'C': 10, 'epsilon': 0.01, 'gamma': 0.1, 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:11:21,221 - Validation MSE: 0.00437
# 2025-01-15 08:11:21,222 -   Evaluating combination 33/279: {'C': 10, 'epsilon': 0.01, 'gamma': 1, 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:12:22,894 - Validation MSE: 0.00506
# 2025-01-15 08:12:22,895 -   Evaluating combination 34/279: {'C': 10, 'epsilon': 0.1, 'gamma': 'scale', 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:12:28,448 - Validation MSE: 0.00677
# 2025-01-15 08:12:28,450 -   Evaluating combination 35/279: {'C': 10, 'epsilon': 0.1, 'gamma': 'auto', 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:12:31,325 - Validation MSE: 0.00500
# 2025-01-15 08:12:31,327 -   Evaluating combination 36/279: {'C': 10, 'epsilon': 0.1, 'gamma': 0.001, 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:12:33,757 - Validation MSE: 0.00557
# 2025-01-15 08:12:33,758 -   Evaluating combination 37/279: {'C': 10, 'epsilon': 0.1, 'gamma': 0.01, 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:12:36,262 - Validation MSE: 0.00517
# 2025-01-15 08:12:36,263 -   Evaluating combination 38/279: {'C': 10, 'epsilon': 0.1, 'gamma': 0.1, 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:12:39,800 - Validation MSE: 0.00496
# 2025-01-15 08:12:39,802 -   Evaluating combination 39/279: {'C': 10, 'epsilon': 0.1, 'gamma': 1, 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:12:45,561 - Validation MSE: 0.00592
# 2025-01-15 08:12:45,562 -   Evaluating combination 40/279: {'C': 10, 'epsilon': 0.2, 'gamma': 'scale', 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:12:46,790 - Validation MSE: 0.01309
# 2025-01-15 08:12:46,791 -   Evaluating combination 41/279: {'C': 10, 'epsilon': 0.2, 'gamma': 'auto', 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:12:47,717 - Validation MSE: 0.01053
# 2025-01-15 08:12:47,718 -   Evaluating combination 42/279: {'C': 10, 'epsilon': 0.2, 'gamma': 0.001, 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:12:48,365 - Validation MSE: 0.01125
# 2025-01-15 08:12:48,367 -   Evaluating combination 43/279: {'C': 10, 'epsilon': 0.2, 'gamma': 0.01, 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:12:49,170 - Validation MSE: 0.01014
# 2025-01-15 08:12:49,172 -   Evaluating combination 44/279: {'C': 10, 'epsilon': 0.2, 'gamma': 0.1, 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:12:50,181 - Validation MSE: 0.01067
# 2025-01-15 08:12:50,182 -   Evaluating combination 45/279: {'C': 10, 'epsilon': 0.2, 'gamma': 1, 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:12:51,537 - Validation MSE: 0.01287
# 2025-01-15 08:12:51,538 -   Evaluating combination 46/279: {'C': 100, 'epsilon': 0.01, 'gamma': 'scale', 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:22:18,638 - Validation MSE: 0.00995
# 2025-01-15 08:22:18,639 -   Evaluating combination 47/279: {'C': 100, 'epsilon': 0.01, 'gamma': 'auto', 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:22:59,064 - Validation MSE: 0.00437
# 2025-01-15 08:22:59,065 -   Evaluating combination 48/279: {'C': 100, 'epsilon': 0.01, 'gamma': 0.001, 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:23:12,489 - Validation MSE: 0.00486
# 2025-01-15 08:23:12,490 -   Evaluating combination 49/279: {'C': 100, 'epsilon': 0.01, 'gamma': 0.01, 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:23:32,318 - Validation MSE: 0.00450
# 2025-01-15 08:23:32,319 -   Evaluating combination 50/279: {'C': 100, 'epsilon': 0.01, 'gamma': 0.1, 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:24:44,452 - Validation MSE: 0.00436
# 2025-01-15 08:24:44,453 -   Evaluating combination 51/279: {'C': 100, 'epsilon': 0.01, 'gamma': 1, 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:32:07,682 - Validation MSE: 0.00715
# 2025-01-15 08:32:07,683 -   Evaluating combination 52/279: {'C': 100, 'epsilon': 0.1, 'gamma': 'scale', 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:32:17,245 - Validation MSE: 0.00789
# 2025-01-15 08:32:17,247 -   Evaluating combination 53/279: {'C': 100, 'epsilon': 0.1, 'gamma': 'auto', 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:32:23,957 - Validation MSE: 0.00493
# 2025-01-15 08:32:23,959 -   Evaluating combination 54/279: {'C': 100, 'epsilon': 0.1, 'gamma': 0.001, 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:32:26,525 - Validation MSE: 0.00539
# 2025-01-15 08:32:26,526 -   Evaluating combination 55/279: {'C': 100, 'epsilon': 0.1, 'gamma': 0.01, 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:32:30,001 - Validation MSE: 0.00502
# 2025-01-15 08:32:30,003 -   Evaluating combination 56/279: {'C': 100, 'epsilon': 0.1, 'gamma': 0.1, 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:32:40,088 - Validation MSE: 0.00501
# 2025-01-15 08:32:40,089 -   Evaluating combination 57/279: {'C': 100, 'epsilon': 0.1, 'gamma': 1, 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:32:57,553 - Validation MSE: 0.00747
# 2025-01-15 08:32:57,555 -   Evaluating combination 58/279: {'C': 100, 'epsilon': 0.2, 'gamma': 'scale', 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:32:59,160 - Validation MSE: 0.01115
# 2025-01-15 08:32:59,162 -   Evaluating combination 59/279: {'C': 100, 'epsilon': 0.2, 'gamma': 'auto', 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:33:00,767 - Validation MSE: 0.01049
# 2025-01-15 08:33:00,768 -   Evaluating combination 60/279: {'C': 100, 'epsilon': 0.2, 'gamma': 0.001, 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:33:01,647 - Validation MSE: 0.01004
# 2025-01-15 08:33:01,648 -   Evaluating combination 61/279: {'C': 100, 'epsilon': 0.2, 'gamma': 0.01, 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:33:02,669 - Validation MSE: 0.01028
# 2025-01-15 08:33:02,672 -   Evaluating combination 62/279: {'C': 100, 'epsilon': 0.2, 'gamma': 0.1, 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:33:04,878 - Validation MSE: 0.01085
# 2025-01-15 08:33:04,880 -   Evaluating combination 63/279: {'C': 100, 'epsilon': 0.2, 'gamma': 1, 'kernel': 'rbf', 'degree': None}
# 2025-01-15 08:33:06,684 - Validation MSE: 0.01240
# 2025-01-15 08:33:06,685 -   Evaluating combination 64/279: {'C': 1, 'epsilon': 0.01, 'gamma': 'scale', 'kernel': 'poly', 'degree': 2}
# 2025-01-15 08:34:47,738 - Validation MSE: 0.00576
# 2025-01-15 08:34:47,739 -   Evaluating combination 65/279: {'C': 1, 'epsilon': 0.01, 'gamma': 'scale', 'kernel': 'poly', 'degree': 3}
# 2025-01-15 08:46:44,064 - Validation MSE: 0.00813
# 2025-01-15 08:46:44,065 -   Evaluating combination 66/279: {'C': 1, 'epsilon': 0.01, 'gamma': 'scale', 'kernel': 'poly', 'degree': 4}
# 2025-01-15 09:43:17,631 - Validation MSE: 0.01603
# 2025-01-15 09:43:17,633 -   Evaluating combination 67/279: {'C': 1, 'epsilon': 0.01, 'gamma': 'auto', 'kernel': 'poly', 'degree': 2}
# 2025-01-15 09:43:27,062 - Validation MSE: 0.00583
# 2025-01-15 09:43:27,064 -   Evaluating combination 68/279: {'C': 1, 'epsilon': 0.01, 'gamma': 'auto', 'kernel': 'poly', 'degree': 3}
# 2025-01-15 09:43:36,838 - Validation MSE: 0.00862
# 2025-01-15 09:43:36,840 -   Evaluating combination 69/279: {'C': 1, 'epsilon': 0.01, 'gamma': 'auto', 'kernel': 'poly', 'degree': 4}
# 2025-01-15 09:43:47,260 - Validation MSE: 0.01423
# 2025-01-15 09:43:47,261 -   Evaluating combination 70/279: {'C': 1, 'epsilon': 0.01, 'gamma': 0.001, 'kernel': 'poly', 'degree': 2}
# 2025-01-15 09:43:57,658 - Validation MSE: 0.01546
# 2025-01-15 09:43:57,660 -   Evaluating combination 71/279: {'C': 1, 'epsilon': 0.01, 'gamma': 0.001, 'kernel': 'poly', 'degree': 3}
# 2025-01-15 09:44:07,733 - Validation MSE: 0.01573
# 2025-01-15 09:44:07,734 -   Evaluating combination 72/279: {'C': 1, 'epsilon': 0.01, 'gamma': 0.001, 'kernel': 'poly', 'degree': 4}
# 2025-01-15 09:44:18,204 - Validation MSE: 0.01573
# 2025-01-15 09:44:18,206 -   Evaluating combination 73/279: {'C': 1, 'epsilon': 0.01, 'gamma': 0.01, 'kernel': 'poly', 'degree': 2}
# 2025-01-15 09:44:27,715 - Validation MSE: 0.00721
# 2025-01-15 09:44:27,717 -   Evaluating combination 74/279: {'C': 1, 'epsilon': 0.01, 'gamma': 0.01, 'kernel': 'poly', 'degree': 3}
# 2025-01-15 09:44:37,594 - Validation MSE: 0.01523
# 2025-01-15 09:44:37,596 -   Evaluating combination 75/279: {'C': 1, 'epsilon': 0.01, 'gamma': 0.01, 'kernel': 'poly', 'degree': 4}
# 2025-01-15 09:44:47,799 - Validation MSE: 0.01571
# 2025-01-15 09:44:47,801 -   Evaluating combination 76/279: {'C': 1, 'epsilon': 0.01, 'gamma': 0.1, 'kernel': 'poly', 'degree': 2}
# 2025-01-15 09:44:57,647 - Validation MSE: 0.00568
# 2025-01-15 09:44:57,648 -   Evaluating combination 77/279: {'C': 1, 'epsilon': 0.01, 'gamma': 0.1, 'kernel': 'poly', 'degree': 3}
# 2025-01-15 09:45:07,411 - Validation MSE: 0.00719
# 2025-01-15 09:45:07,413 -   Evaluating combination 78/279: {'C': 1, 'epsilon': 0.01, 'gamma': 0.1, 'kernel': 'poly', 'degree': 4}
# 2025-01-15 09:45:17,383 - Validation MSE: 0.01006
# 2025-01-15 09:45:17,384 -   Evaluating combination 79/279: {'C': 1, 'epsilon': 0.01, 'gamma': 1, 'kernel': 'poly', 'degree': 2}
# 2025-01-15 09:45:50,479 - Validation MSE: 0.00570
# 2025-01-15 09:45:50,481 -   Evaluating combination 80/279: {'C': 1, 'epsilon': 0.01, 'gamma': 1, 'kernel': 'poly', 'degree': 3}
# 2025-01-15 09:47:34,516 - Validation MSE: 0.00745
# 2025-01-15 09:47:34,517 -   Evaluating combination 81/279: {'C': 1, 'epsilon': 0.01, 'gamma': 1, 'kernel': 'poly', 'degree': 4}
# 2025-01-15 09:52:11,422 - Validation MSE: 0.01061
# 2025-01-15 09:52:11,423 -   Evaluating combination 82/279: {'C': 1, 'epsilon': 0.1, 'gamma': 'scale', 'kernel': 'poly', 'degree': 2}
# 2025-01-15 09:52:39,420 - Validation MSE: 0.00608
# 2025-01-15 09:52:39,421 -   Evaluating combination 83/279: {'C': 1, 'epsilon': 0.1, 'gamma': 'scale', 'kernel': 'poly', 'degree': 3}
# 2025-01-15 09:55:23,976 - Validation MSE: 0.00741
# 2025-01-15 09:55:23,978 -   Evaluating combination 84/279: {'C': 1, 'epsilon': 0.1, 'gamma': 'scale', 'kernel': 'poly', 'degree': 4}
# 2025-01-15 10:04:39,195 - Validation MSE: 0.01343
# 2025-01-15 10:04:39,196 -   Evaluating combination 85/279: {'C': 1, 'epsilon': 0.1, 'gamma': 'auto', 'kernel': 'poly', 'degree': 2}
# 2025-01-15 10:04:41,543 - Validation MSE: 0.00653
# 2025-01-15 10:04:41,545 -   Evaluating combination 86/279: {'C': 1, 'epsilon': 0.1, 'gamma': 'auto', 'kernel': 'poly', 'degree': 3}
# 2025-01-15 10:04:45,519 - Validation MSE: 0.01047
# 2025-01-15 10:04:45,520 -   Evaluating combination 87/279: {'C': 1, 'epsilon': 0.1, 'gamma': 'auto', 'kernel': 'poly', 'degree': 4}
# 2025-01-15 10:04:50,730 - Validation MSE: 0.01477
# 2025-01-15 10:04:50,731 -   Evaluating combination 88/279: {'C': 1, 'epsilon': 0.1, 'gamma': 0.001, 'kernel': 'poly', 'degree': 2}
# 2025-01-15 10:04:55,851 - Validation MSE: 0.01573
# 2025-01-15 10:04:55,852 -   Evaluating combination 89/279: {'C': 1, 'epsilon': 0.1, 'gamma': 0.001, 'kernel': 'poly', 'degree': 3}
# 2025-01-15 10:05:00,793 - Validation MSE: 0.01591
# 2025-01-15 10:05:00,794 -   Evaluating combination 90/279: {'C': 1, 'epsilon': 0.1, 'gamma': 0.001, 'kernel': 'poly', 'degree': 4}
# 2025-01-15 10:05:06,033 - Validation MSE: 0.01591
# 2025-01-15 10:05:06,034 -   Evaluating combination 91/279: {'C': 1, 'epsilon': 0.1, 'gamma': 0.01, 'kernel': 'poly', 'degree': 2}
# 2025-01-15 10:05:09,567 - Validation MSE: 0.00938
# 2025-01-15 10:05:09,574 -   Evaluating combination 92/279: {'C': 1, 'epsilon': 0.1, 'gamma': 0.01, 'kernel': 'poly', 'degree': 3}
# 2025-01-15 10:05:14,667 - Validation MSE: 0.01555
# 2025-01-15 10:05:14,669 -   Evaluating combination 93/279: {'C': 1, 'epsilon': 0.1, 'gamma': 0.01, 'kernel': 'poly', 'degree': 4}
# 2025-01-15 10:05:19,916 - Validation MSE: 0.01590
# 2025-01-15 10:05:19,917 -   Evaluating combination 94/279: {'C': 1, 'epsilon': 0.1, 'gamma': 0.1, 'kernel': 'poly', 'degree': 2}
# 2025-01-15 10:05:22,089 - Validation MSE: 0.00620
# 2025-01-15 10:05:22,091 -   Evaluating combination 95/279: {'C': 1, 'epsilon': 0.1, 'gamma': 0.1, 'kernel': 'poly', 'degree': 3}
# 2025-01-15 10:05:25,127 - Validation MSE: 0.00819
# 2025-01-15 10:05:25,128 -   Evaluating combination 96/279: {'C': 1, 'epsilon': 0.1, 'gamma': 0.1, 'kernel': 'poly', 'degree': 4}
# 2025-01-15 10:05:29,736 - Validation MSE: 0.01153
# 2025-01-15 10:05:29,737 -   Evaluating combination 97/279: {'C': 1, 'epsilon': 0.1, 'gamma': 1, 'kernel': 'poly', 'degree': 2}
# 2025-01-15 10:05:38,480 - Validation MSE: 0.00607
# 2025-01-15 10:05:38,481 -   Evaluating combination 98/279: {'C': 1, 'epsilon': 0.1, 'gamma': 1, 'kernel': 'poly', 'degree': 3}
# 2025-01-15 10:06:06,748 - Validation MSE: 0.00706
# 2025-01-15 10:06:06,749 -   Evaluating combination 99/279: {'C': 1, 'epsilon': 0.1, 'gamma': 1, 'kernel': 'poly', 'degree': 4}
# 2025-01-15 10:07:09,506 - Validation MSE: 0.00914
# 2025-01-15 10:07:09,507 -   Evaluating combination 100/279: {'C': 1, 'epsilon': 0.2, 'gamma': 'scale', 'kernel': 'poly', 'degree': 2}
# 2025-01-15 10:07:14,864 - Validation MSE: 0.01144
# 2025-01-15 10:07:14,866 -   Evaluating combination 101/279: {'C': 1, 'epsilon': 0.2, 'gamma': 'scale', 'kernel': 'poly', 'degree': 3}
# 2025-01-15 10:07:30,294 - Validation MSE: 0.01259
# 2025-01-15 10:07:30,296 -   Evaluating combination 102/279: {'C': 1, 'epsilon': 0.2, 'gamma': 'scale', 'kernel': 'poly', 'degree': 4}
# 2025-01-15 10:08:06,055 - Validation MSE: 0.01455
# 2025-01-15 10:08:06,057 -   Evaluating combination 103/279: {'C': 1, 'epsilon': 0.2, 'gamma': 'auto', 'kernel': 'poly', 'degree': 2}
# 2025-01-15 10:08:06,647 - Validation MSE: 0.01279
# 2025-01-15 10:08:06,649 -   Evaluating combination 104/279: {'C': 1, 'epsilon': 0.2, 'gamma': 'auto', 'kernel': 'poly', 'degree': 3}
# 2025-01-15 10:08:07,559 - Validation MSE: 0.01441
# 2025-01-15 10:08:07,560 -   Evaluating combination 105/279: {'C': 1, 'epsilon': 0.2, 'gamma': 'auto', 'kernel': 'poly', 'degree': 4}
# 2025-01-15 10:08:08,793 - Validation MSE: 0.01550
# 2025-01-15 10:08:08,794 -   Evaluating combination 106/279: {'C': 1, 'epsilon': 0.2, 'gamma': 0.001, 'kernel': 'poly', 'degree': 2}
# 2025-01-15 10:08:10,248 - Validation MSE: 0.01588
# 2025-01-15 10:08:10,250 -   Evaluating combination 107/279: {'C': 1, 'epsilon': 0.2, 'gamma': 0.001, 'kernel': 'poly', 'degree': 3}
# 2025-01-15 10:08:11,656 - Validation MSE: 0.01592
# 2025-01-15 10:08:11,658 -   Evaluating combination 108/279: {'C': 1, 'epsilon': 0.2, 'gamma': 0.001, 'kernel': 'poly', 'degree': 4}
# 2025-01-15 10:08:13,115 - Validation MSE: 0.01592
# 2025-01-15 10:08:13,117 -   Evaluating combination 109/279: {'C': 1, 'epsilon': 0.2, 'gamma': 0.01, 'kernel': 'poly', 'degree': 2}
# 2025-01-15 10:08:14,001 - Validation MSE: 0.01428
# 2025-01-15 10:08:14,003 -   Evaluating combination 110/279: {'C': 1, 'epsilon': 0.2, 'gamma': 0.01, 'kernel': 'poly', 'degree': 3}
# 2025-01-15 10:08:15,325 - Validation MSE: 0.01579
# 2025-01-15 10:08:15,326 -   Evaluating combination 111/279: {'C': 1, 'epsilon': 0.2, 'gamma': 0.01, 'kernel': 'poly', 'degree': 4}
# 2025-01-15 10:08:16,759 - Validation MSE: 0.01592
# 2025-01-15 10:08:16,760 -   Evaluating combination 112/279: {'C': 1, 'epsilon': 0.2, 'gamma': 0.1, 'kernel': 'poly', 'degree': 2}
# 2025-01-15 10:08:17,406 - Validation MSE: 0.01229
# 2025-01-15 10:08:17,408 -   Evaluating combination 113/279: {'C': 1, 'epsilon': 0.2, 'gamma': 0.1, 'kernel': 'poly', 'degree': 3}
# 2025-01-15 10:08:18,267 - Validation MSE: 0.01320
# 2025-01-15 10:08:18,269 -   Evaluating combination 114/279: {'C': 1, 'epsilon': 0.2, 'gamma': 0.1, 'kernel': 'poly', 'degree': 4}
# 2025-01-15 10:08:19,385 - Validation MSE: 0.01431
# 2025-01-15 10:08:19,387 -   Evaluating combination 115/279: {'C': 1, 'epsilon': 0.2, 'gamma': 1, 'kernel': 'poly', 'degree': 2}
# 2025-01-15 10:08:21,470 - Validation MSE: 0.01162
# 2025-01-15 10:08:21,472 -   Evaluating combination 116/279: {'C': 1, 'epsilon': 0.2, 'gamma': 1, 'kernel': 'poly', 'degree': 3}
# 2025-01-15 10:08:25,897 - Validation MSE: 0.01230
# 2025-01-15 10:08:25,898 -   Evaluating combination 117/279: {'C': 1, 'epsilon': 0.2, 'gamma': 1, 'kernel': 'poly', 'degree': 4}
# 2025-01-15 10:08:36,034 - Validation MSE: 0.01303
# 2025-01-15 10:08:36,035 -   Evaluating combination 118/279: {'C': 10, 'epsilon': 0.01, 'gamma': 'scale', 'kernel': 'poly', 'degree': 2}
# 2025-01-15 10:21:54,896 - Validation MSE: 0.00583
# 2025-01-15 10:21:54,898 -   Evaluating combination 119/279: {'C': 10, 'epsilon': 0.01, 'gamma': 'scale', 'kernel': 'poly', 'degree': 3}
# 2025-01-15 12:23:23,386 - Validation MSE: 0.01049
# 2025-01-15 12:23:23,387 -   Evaluating combination 120/279: {'C': 10, 'epsilon': 0.01, 'gamma': 'scale', 'kernel': 'poly', 'degree': 4}

# %% [markdown]
# ## 9. Storing Results

# %%
# Convert the results list to a DataFrame
results_df = pd.DataFrame(results)

# Expand the hyperparameters dictionary into separate columns for clarity
hyperparams_df = results_df['Best_Hyperparameters'].apply(pd.Series)

# Combine the main dataframe with hyperparameters
final_results_df = pd.concat([results_df.drop('Best_Hyperparameters', axis=1), hyperparams_df], axis=1)

# Display the final dataframe
print("Final Results DataFrame:")
final_results_df
