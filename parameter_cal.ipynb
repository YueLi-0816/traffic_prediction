# %%
import pandas as pd

# %% [markdown]
# # 1. Best Hyperparameter

# %% [markdown]
# ## 1.1 CNN
# After COVID

# %%
# Define the best hyperparameters for each input length

best_hyperparameters = {
    24: {
        'filters': 128,
        'kernel_size': 3,
        'dropout': 0.3,
        'learning_rate': 0.0005,
        'batch_size': 64
    },
    48: {
        'filters': 64,
        'kernel_size': 3,
        'dropout': 0.0,
        'learning_rate': 0.0005,
        'batch_size': 128
    },
    72: {
        'filters': 64,
        'kernel_size': 5,
        'dropout': 0.3,
        'learning_rate': 0.001,
        'batch_size': 64
    },
    96: {
        'filters': 64,
        'kernel_size': 3,
        'dropout': 0.0,
        'learning_rate': 0.0005,
        'batch_size': 128
    },
    120: {
        'filters': 64,
        'kernel_size': 3,
        'dropout': 0.1,
        'learning_rate': 0.0005,
        'batch_size': 128
    },
    144: {
        'filters': 32,
        'kernel_size': 2,
        'dropout': 0.3,
        'learning_rate': 0.0005,
        'batch_size': 32
    },
    168: {
        'filters': 32,
        'kernel_size': 2,
        'dropout': 0.1,
        'learning_rate': 0.0005,
        'batch_size': 64
    },
    192: {
        'filters': 128,
        'kernel_size': 3,
        'dropout': 0.2,
        'learning_rate': 0.0001,
        'batch_size': 32
    },
    216: {
        'filters': 64,
        'kernel_size': 3,
        'dropout': 0.2,
        'learning_rate': 0.0001,
        'batch_size': 32
    },
    240: {
        'filters': 32,
        'kernel_size': 5,
        'dropout': 0.0,
        'learning_rate': 0.0001,
        'batch_size': 32
    },
    264: {
        'filters': 128,
        'kernel_size': 3,
        'dropout': 0.3,
        'learning_rate': 0.0005,
        'batch_size': 32
    },
    288: {
        'filters': 32,
        'kernel_size': 3,
        'dropout': 0.3,
        'learning_rate': 0.0001,
        'batch_size': 32
    },
    312: {
        'filters': 32,
        'kernel_size': 2,
        'dropout': 0.1,
        'learning_rate': 0.0005,
        'batch_size': 128
    },
    336: {
        'filters': 64,
        'kernel_size': 2,
        'dropout': 0.2,
        'learning_rate': 0.0001,
        'batch_size': 32
    },
    360: {
        'filters': 32,
        'kernel_size': 2,
        'dropout': 0.3,
        'learning_rate': 0.0001,
        'batch_size': 64
    },
    384: {
        'filters': 32,
        'kernel_size': 2,
        'dropout': 0.1,
        'learning_rate': 0.0001,
        'batch_size': 128
    },
    408: {
        'filters': 32,
        'kernel_size': 2,
        'dropout': 0.1,
        'learning_rate': 0.001,
        'batch_size': 128
    },
    432: {
        'filters': 32,
        'kernel_size': 3,
        'dropout': 0.0,
        'learning_rate': 0.0001,
        'batch_size': 32
    },
    456: {
        'filters': 32,
        'kernel_size': 3,
        'dropout': 0.0,
        'learning_rate': 0.0001,
        'batch_size': 64
    },
    480: {
        'filters': 64,
        'kernel_size': 2,
        'dropout': 0.2,
        'learning_rate': 0.0001,
        'batch_size': 32
    },
    504: {
        'filters': 32,
        'kernel_size': 2,
        'dropout': 0.1,
        'learning_rate': 0.0001,
        'batch_size': 64
    }
}

# %% [markdown]
# Entire dataset

# %%
best_hyperparameters_cnn = {
    24: {
        'filters': 128,
        'kernel_size': 3,
        'dropout': 0.3,
        'learning_rate': 0.0001,
        'batch_size': 64
    },
    48: {
        'filters': 128,
        'kernel_size': 3,
        'dropout': 0.3,
        'learning_rate': 0.0001,
        'batch_size': 128
    },
    72: {
        'filters': 128,
        'kernel_size': 5,
        'dropout': 0.1,
        'learning_rate': 0.0001,
        'batch_size': 64
    },
    96: {
        'filters': 64,
        'kernel_size': 5,
        'dropout': 0.3,
        'learning_rate': 0.0001,
        'batch_size': 32
    },
    120: {
        'filters': 64,
        'kernel_size': 5,
        'dropout': 0.2,
        'learning_rate': 0.0005,
        'batch_size': 128
    },
    144: {
        'filters': 64,
        'kernel_size': 5,
        'dropout': 0.3,
        'learning_rate': 0.0001,
        'batch_size': 128
    },
    168: {
        'filters': 64,
        'kernel_size': 5,
        'dropout': 0.3,
        'learning_rate': 0.0005,
        'batch_size': 64
    },
    192: {
        'filters': 32,
        'kernel_size': 5,
        'dropout': 0.3,
        'learning_rate': 0.001,
        'batch_size': 128
    },
    216: {
        'filters': 64,
        'kernel_size': 5,
        'dropout': 0.3,
        'learning_rate': 0.0001,
        'batch_size': 64
    },
    240: {
        'filters': 32,
        'kernel_size': 3,
        'dropout': 0.3,
        'learning_rate': 0.0001,
        'batch_size': 32
    },
    264: {
        'filters': 64,
        'kernel_size': 3,
        'dropout': 0.3,
        'learning_rate': 0.0001,
        'batch_size': 128
    },
    288: {
        'filters': 128,
        'kernel_size': 2,
        'dropout': 0.3,
        'learning_rate': 0.001,
        'batch_size': 128
    },
    312: {
        'filters': 32,
        'kernel_size': 3,
        'dropout': 0.3,
        'learning_rate': 0.0005,
        'batch_size': 128
    },
    336: {
        'filters': 32,
        'kernel_size': 3,
        'dropout': 0.3,
        'learning_rate': 0.0001,
        'batch_size': 128
    },
    360: {
        'filters': 32,
        'kernel_size': 2,
        'dropout': 0.2,
        'learning_rate': 0.0001,
        'batch_size': 32
    },
    384: {
        'filters': 32,
        'kernel_size': 3,
        'dropout': 0.3,
        'learning_rate': 0.0001,
        'batch_size': 64
    },
    408: {
        'filters': 32,
        'kernel_size': 3,
        'dropout': 0.3,
        'learning_rate': 0.0001,
        'batch_size': 64
    },
    432: {
        'filters': 32,
        'kernel_size': 2,
        'dropout': 0.2,
        'learning_rate': 0.0001,
        'batch_size': 64
    },
    456: {
        'filters': 32,
        'kernel_size': 2,
        'dropout': 0.3,
        'learning_rate': 0.0001,
        'batch_size': 128
    },
    480: {
        'filters': 32,
        'kernel_size': 3,
        'dropout': 0.3,
        'learning_rate': 0.0001,
        'batch_size': 128
    },
    504: {
        'filters': 32,
        'kernel_size': 2,
        'dropout': 0.2,
        'learning_rate': 0.0001,
        'batch_size': 64
    }
}

# %% [markdown]
# ## 1.2 LSTM
# After COVID

# %%
best_hyperparameters_improved_model = {
    24: {
        'units': 32,
        'dropout': 0.2,
        'learning_rate': 0.001,
        'batch_size': 32
    },
    48: {
        'units': 128,
        'dropout': 0.2,
        'learning_rate': 0.01,
        'batch_size': 64
    },
    72: {
        'units': 256,
        'dropout': 0.0,
        'learning_rate': 0.001,
        'batch_size': 32
    },
    96: {
        'units': 64,
        'dropout': 0.2,
        'learning_rate': 0.01,
        'batch_size': 32
    },
    120: {
        'units': 32,
        'dropout': 0.2,
        'learning_rate': 0.001,
        'batch_size': 32
    },
    144: {
        'units': 128,
        'dropout': 0.3,
        'learning_rate': 0.01,
        'batch_size': 32
    },
    168: {
        'units': 32,
        'dropout': 0.0,
        'learning_rate': 0.0005,
        'batch_size': 32
    },
    192: {
        'units': 64,
        'dropout': 0.2,
        'learning_rate': 0.01,
        'batch_size': 128
    },
    216: {
        'units': 128,
        'dropout': 0.1,
        'learning_rate': 0.01,
        'batch_size': 32
    },
    240: {
        'units': 128,
        'dropout': 0.1,
        'learning_rate': 0.01,
        'batch_size': 32
    },
    264: {
        'units': 128,
        'dropout': 0.3,
        'learning_rate': 0.01,
        'batch_size': 32
    },
    288: {
        'units': 128,
        'dropout': 0.0,
        'learning_rate': 0.01,
        'batch_size': 32
    },
    312: {
        'units': 64,
        'dropout': 0.2,
        'learning_rate': 0.01,
        'batch_size': 64
    },
    336: {
        'units': 128,
        'dropout': 0.3,
        'learning_rate': 0.01,
        'batch_size': 32
    },
    360: {
        'units': 128,
        'dropout': 0.2,
        'learning_rate': 0.001,
        'batch_size': 32
    },
    384: {
        'units': 64,
        'dropout': 0.2,
        'learning_rate': 0.01,
        'batch_size': 32
    },
    408: {
        'units': 128,
        'dropout': 0.2,
        'learning_rate': 0.01,
        'batch_size': 32
    },
    432: {
        'units': 64,
        'dropout': 0.3,
        'learning_rate': 0.01,
        'batch_size': 32
    },
    456: {
        'units': 64,
        'dropout': 0.3,
        'learning_rate': 0.01,
        'batch_size': 32
    },
    480: {
        'units': 32,
        'dropout': 0.4,
        'learning_rate': 0.01,
        'batch_size': 32
    },
    504: {
        'units': 128,
        'dropout': 0.4,
        'learning_rate': 0.01,
        'batch_size': 32
    }
}

# %% [markdown]
# Entire dataset

# %%
best_hyperparameters_improved_model_lstm = {
    24: {
        'units': 64,
        'dropout': 0.2,
        'learning_rate': 0.001,
        'batch_size': 32
    },
    48: {
        'units': 256,
        'dropout': 0.2,
        'learning_rate': 0.01,
        'batch_size': 32
    },
    72: {
        'units': 256,
        'dropout': 0.1,
        'learning_rate': 0.001,
        'batch_size': 128
    },
    96: {
        'units': 256,
        'dropout': 0.4,
        'learning_rate': 0.001,
        'batch_size': 32
    },
    120: {
        'units': 128,
        'dropout': 0.1,
        'learning_rate': 0.001,
        'batch_size': 64
    },
    144: {
        'units': 256,
        'dropout': 0.2,
        'learning_rate': 0.001,
        'batch_size': 64
    },
    168: {
        'units': 256,
        'dropout': 0.3,
        'learning_rate': 0.001,
        'batch_size': 64
    },
    192: {
        'units': 256,
        'dropout': 0.4,
        'learning_rate': 0.001,
        'batch_size': 32
    },
    216: {
        'units': 256,
        'dropout': 0.4,
        'learning_rate': 0.001,
        'batch_size': 32
    },
    240: {
        'units': 64,
        'dropout': 0.4,
        'learning_rate': 0.005,
        'batch_size': 64
    },
    264: {
        'units': 256,
        'dropout': 0.4,
        'learning_rate': 0.001,
        'batch_size': 32
    },
    288: {
        'units': 64,
        'dropout': 0.3,
        'learning_rate': 0.001,
        'batch_size': 64
    },
    312: {
        'units': 32,
        'dropout': 0.2,
        'learning_rate': 0.001,
        'batch_size': 32
    },
    336: {
        'units': 256,
        'dropout': 0.1,
        'learning_rate': 0.01,
        'batch_size': 64
    },
    360: {
        'units': 32,
        'dropout': 0.1,
        'learning_rate': 0.001,
        'batch_size': 32
    },
    384: {
        'units': 256,
        'dropout': 0.3,
        'learning_rate': 0.001,
        'batch_size': 64
    },
    408: {
        'units': 256,
        'dropout': 0.4,
        'learning_rate': 0.001,
        'batch_size': 64
    },
    432: {
        'units': 128,
        'dropout': 0.4,
        'learning_rate': 0.001,
        'batch_size': 64
    },
    456: {
        'units': 128,
        'dropout': 0.0,
        'learning_rate': 0.001,
        'batch_size': 32
    },
    480: {
        'units': 256,
        'dropout': 0.1,
        'learning_rate': 0.001,
        'batch_size': 64
    },
    504: {
        'units': 128,
        'dropout': 0.0,
        'learning_rate': 0.001,
        'batch_size': 32
    }
}

# %% [markdown]
# # 2. Calculate the number of parameters

# %% [markdown]
# ## 2.1 CNN

# %%
def calculate_cnn_params(hyperparams, input_length):
    filters = hyperparams['filters']
    kernel_size = hyperparams['kernel_size']
    dropout = hyperparams['dropout']  # Not used for parameter calculation
    output_neurons = 6

    # First Conv1D Layer
    first_conv_params = (kernel_size * 1 + 1) * filters

    # Second Conv1D Layer
    second_conv_params = (kernel_size * filters + 1) * filters

    # Flatten Layer: Compute input size after pooling
    pooled_length = (input_length - 2 * (kernel_size - 1)) // 2  # Assuming valid padding
    flattened_size = pooled_length * filters

    # Dense Layer
    dense_params = (flattened_size + 1) * output_neurons

    # Total Parameters
    total_params = first_conv_params + second_conv_params + dense_params
    return total_params

# %%
# Calculate parameters for each input length
results_cnn = []
for length, hyperparams in best_hyperparameters.items():
    total_params = calculate_cnn_params(hyperparams, length)
    results_cnn.append({'Input Length': length, 'Total Params (CNN-Dataset After COVID)': total_params})

# Create a dataframe for the results
df_cnn = pd.DataFrame(results_cnn)
df_cnn['Total Params (CNN-Dataset After COVID)'] = df_cnn['Total Params (CNN-Dataset After COVID)']#.apply(lambda x: '{:,.0f}'.format(x))
df_cnn.sort_values(by='Input Length', inplace=True)

# %%
# Calculate parameters for each input length
results_cnn_all = []
for length, hyperparams in best_hyperparameters_cnn.items():
    total_params = calculate_cnn_params(hyperparams, length)
    results_cnn_all.append({'Input Length': length, 'Total Params (CNN-Entire Dataset)': total_params})

# Create a dataframe for the results
df_cnn_all = pd.DataFrame(results_cnn_all)
df_cnn_all['Total Params (CNN-Entire Dataset)'] = df_cnn_all['Total Params (CNN-Entire Dataset)']#.apply(lambda x: '{:,.0f}'.format(x))
df_cnn_all.sort_values(by='Input Length', inplace=True)

# %% [markdown]
# ## 2.2 LSTM

# %%
def calculate_lstm_params(hyperparams, input_length):
    units = hyperparams['units']
    output_neurons = 6  # Output layer size
    
    # First LSTM Layer
    first_lstm_params = 4 * ((1 + units) * units + units)  # input_size = 1 (from input_shape)

    # Second LSTM Layer
    second_lstm_params = 4 * ((units + units) * units + units)  # input_size = units

    # Dense Layer
    dense_params = (units + 1) * output_neurons

    # Total Parameters
    total_params = first_lstm_params + second_lstm_params + dense_params
    return total_params

# %%
# Calculate parameters for each input length
results_lstm = []
for length, hyperparams in best_hyperparameters_improved_model.items():
    total_params = calculate_lstm_params(hyperparams, length)
    results_lstm.append({'Input Length': length, 'Total Params (LSTM-Dataset After COVID)': total_params})

# Create a dataframe for the results
df_lstm = pd.DataFrame(results_lstm)
df_lstm['Total Params (LSTM-Dataset After COVID)'] = df_lstm['Total Params (LSTM-Dataset After COVID)']#.apply(lambda x: '{:,.0f}'.format(x))
df_lstm.sort_values(by='Input Length', inplace=True)

# %%
# Calculate parameters for each input length
results_lstm_all = []
for length, hyperparams in best_hyperparameters_improved_model_lstm.items():
    total_params = calculate_lstm_params(hyperparams, length)
    results_lstm_all.append({'Input Length': length, 'Total Params (LSTM-Entire Dataset)': total_params})

# Create a dataframe for the results
df_lstm_all = pd.DataFrame(results_lstm_all)
df_lstm_all['Total Params (LSTM-Entire Dataset)'] = df_lstm_all['Total Params (LSTM-Entire Dataset)']#.apply(lambda x: '{:,.0f}'.format(x))
df_lstm_all.sort_values(by='Input Length', inplace=True)

# %% [markdown]
# ## 2.3 All parameters

# %%
from functools import reduce

# List of DataFrames
dfs = [df_cnn, df_cnn_all, df_lstm, df_lstm_all]

# Merging all DataFrames in the list on 'ID'
df_all = reduce(lambda left, right: pd.merge(left, right, on='Input Length'), dfs)
df_all
# Out:
#     Input Length  Total Params (CNN-Dataset After COVID)  \
# 0             24                                   57478
# 1             48                                   21062
# 2             72                                   33222
# 3             96                                   30278
# 4            120                                   34886
# 5            144                                   15814
# 6            168                                   18118
# 7            192                                  121990
# 8            216                                   53318
# 9            240                                   27622
# 10           264                                  149638
# 11           288                                   30502
# 12           312                                   31942
# 13           336                                   72582
# 14           360                                   36550
# 15           384                                   38854
# 16           408                                   41158
# 17           432                                   44326
# 18           456                                   46630
# 19           480                                  100230
# 20           504                                   50374
#
#     Total Params (CNN-Entire Dataset)  \
# 0                               57478
# 1                               66694
# 2                              107398
# 3                               37830
# 4                               42438
# 5                               47046
# 6                               51654
# 7                               23014
# 8                               60870
# 9                               25894
# 10                              62534
# 11                             143110
# 12                              32806
# 13                              35110
# 14                              36550
# 15                              39718
# 16                              42022
# 17                              43462
# 18                              45766
# 19                              48934
# 20                              50374
#
#     Total Params (LSTM-Dataset After COVID)  \
# 0                                     12870
# 1                                    198918
# 2                                    791046
# 3                                     50310
# 4                                     12870
# 5                                    198918
# 6                                     12870
# 7                                     50310
# 8                                    198918
# 9                                    198918
# 10                                   198918
# 11                                   198918
# 12                                    50310
# 13                                   198918
# 14                                   198918
# 15                                    50310
# 16                                   198918
# 17                                    50310
# 18                                    50310
# 19                                    12870
# 20                                   198918
#
#     Total Params (LSTM-Entire Dataset)
# 0                                50310
# 1                               791046
# 2                               791046
# 3                               791046
# 4                               198918
# 5                               791046
# 6                               791046
# 7                               791046
# 8                               791046
# 9                                50310
# 10                              791046
# 11                               50310
# 12                               12870
# 13                              791046
# 14                               12870
# 15                              791046
# 16                              791046
# 17                              198918
# 18                              198918
# 19                              791046
# 20                              198918

# %% [markdown]
# # 3. Merge the model size with performance

# %%
data_cnn = {
    "Input Length": [24.0, 48.0, 72.0, 96.0, 120.0, 144.0, 168.0, 192.0, 216.0, 240.0, 264.0, 288.0, 312.0, 336.0, 360.0, 384.0, 408.0, 432.0, 456.0, 480.0, 504.0],
    "MAE_test": [24.013374, 23.860861, 24.182598, 23.677729, 23.729933, 21.232649, 19.274195, 19.789064, 19.426317, 20.782852, 26.236981, 22.778363, 24.925906, 22.435182, 26.720434, 22.75406, 31.26819, 20.009249, 20.731856, 33.60486, 29.097511],
    "RMSE_test": [31.32954, 31.093594, 31.408258, 30.569038, 30.986183, 28.287619, 25.466699, 26.215858, 25.884107, 26.867513, 33.25743, 29.353605, 31.475169, 28.44872, 32.577966, 28.369423, 36.835476, 26.025717, 26.720035, 38.749481, 34.670595],
    "MAPE (%)_test": [21.814042, 20.780494, 21.04196, 20.967417, 19.940819, 17.691513, 16.566392, 17.308632, 16.361286, 18.003449, 19.037552, 16.515616, 18.104299, 16.589305, 19.543632, 17.32813, 23.351625, 15.601561, 16.090402, 25.80529, 22.814711],
}

# %%
data_cnn_all = {
    "Input Length": [24.0, 48.0, 72.0, 96.0, 120.0, 144.0, 168.0, 192.0, 216.0, 240.0, 264.0, 288.0, 312.0, 336.0, 360.0, 384.0, 408.0, 432.0, 456.0, 480.0, 504.0],
    "MAE_test": [28.501066, 28.189345, 27.759121, 27.804334, 28.090787, 27.491200, 27.205093, 27.423619, 26.961792, 27.179082, 27.386442, 28.019475, 27.975598, 27.972771, 28.255259, 28.617412, 28.924407, 29.426706, 29.351807, 29.505743, 29.507149],
    "RMSE_test": [41.511618, 41.141034, 40.713072, 40.857774, 40.849912, 40.352429, 40.429996, 40.783980, 40.359042, 40.954109, 41.019110, 41.753962, 41.981563, 42.199263, 42.409564, 43.235708, 44.022783, 44.591065, 43.719049, 44.027994, 43.609287],
    "MAPE (%)_test": [36.768265, 36.742039, 36.452420, 37.387532, 39.058473, 37.347456, 37.022649, 38.620251, 37.234617, 37.609315, 37.469026, 38.702801, 38.577672, 38.551538, 39.370629, 39.110817, 39.113291, 39.689643, 41.741805, 41.968773, 42.855822],
}

# %%
data_lstm = {
    "Input Length": [24.0, 48.0, 72.0, 96.0, 120.0, 144.0, 168.0, 192.0, 216.0, 240.0, 264.0, 288.0, 312.0, 336.0, 360.0, 384.0,
# ## 3.1 Average the model size across all the input length

# %%
mean_param = pd.DataFrame([df_all.mean()])
#drop the column 'Input Length'
mean_param.drop('Input Length', axis=1, inplace=True)
#rename column to only keep the words in ()
mean_param.columns = mean_param.columns.str.extract(r'\((.*?)\)', expand=False)
#replace the indx of first row with name 'model size'
mean_param.rename(index={mean_param.index[0]: 'Model Size'}, inplace=True)
mean_param
# Out:
#             CNN-Dataset After COVID  CNN-Entire Dataset  \
# Model Size             50313.047619        52414.380952
#
#             LSTM-Dataset After COVID  LSTM-Entire Dataset
# Model Size             149217.428571        498328.285714

# %% [markdown]
# ## 3.2 Average performance of each model

# %%
def mean_perform(data):
    
    # Create a DataFrame from the dictionary
    df = pd.DataFrame(data)
    # Calculate the mean of each column
    mean_series = df.mean()
    # Convert the Series to a DataFrame (one row)
    mean_perform = pd.DataFrame([mean_series])
    mean_perform.drop('Input Length', axis=1, inplace=True)
    
    return mean_perform

# %%
cnn_post = mean_perform(data_cnn)
cnn_all = mean_perform(data_cnn_all)
lstm_post = mean_perform(data_lstm)
lstm_all = mean_perform(data_lstm_all)
lag_llama_post = mean_perform(data_lag_llama)
lag_llama_all = mean_perform(data_lag_llama_all)
model_1_post = mean_perform(model_1_data)
model_2_post = mean_perform(model_2_data)
model_3_post = mean_perform(model_3_data)
model_4_post = mean_perform(model_4_data)
model_5_post = mean_perform(model_5_data)
model_1_all = mean_perform(model_1_updated_data)
model_2_all = mean_perform(model_2_updated_data)
model_3_all = mean_perform(model_3_updated_data)
model_4_all = mean_perform(model_4_updated_data)
model_5_all = mean_perform(model_5_updated_data)

# %%
cnn_post.rename(index={cnn_post.index[0]: 'CNN-Dataset After COVID'}, inplace=True)
cnn_all.rename(index={cnn_all.index[0]: 'CNN-Entire Dataset'}, inplace=True)
lstm_post.rename(index={lstm_post.index[0]: 'LSTM-Dataset After COVID'}, inplace=True)
lstm_all.rename(index={lstm_all.index[0]: 'LSTM-Entire Dataset'}, inplace=True)
lag_llama_post.rename(index={lag_llama_post.index[0]: 'Lag-Llama-Dataset After COVID'}, inplace=True)
lag_llama_all.rename(index={lag_llama_all.index[0]: 'Lag-Llama-Entire Dataset'}, inplace=True)
model_1_post.rename(index={model_1_post.index[0]: 'Chronos(tiny)-Dataset After COVID'}, inplace=True)
model_2_post.rename(index={model_2_post.index[0]: 'Chronos(mini)-Dataset After COVID'}, inplace=True)
model_3_post.rename(index={model_3_post.index[0]: 'Chronos(small)-Dataset After COVID'}, inplace=True)
model_4_post.rename(index={model_4_post.index[0]: 'Chronos(base)-Dataset After COVID'}, inplace=True)
model_5_post.rename(index={model_5_post.index[0]: 'Chronos(large)-Dataset After COVID'}, inplace=True)
model_1_all.rename(index={model_1_all.index[0]: 'Chronos(tiny)-Entire Dataset'}, inplace=True)
model_2_all.rename(index={model_2_all.index[0]: 'Chronos(mini)-Entire Dataset'}, inplace=True)
model_3_all.rename(index={model_3_all.index[0]: 'Chronos(small)-Entire Dataset'}, inplace=True)
model_4_all.rename(index={model_4_all.index[0]: 'Chronos(base)-Entire Dataset'}, inplace=True)
model_5_all.rename(index={model_5_all.index[0]: 'Chronos(large)-Entire Dataset'}, inplace=True)
mean_perform_all = pd.concat([cnn_post.T, cnn_all.T, lstm_post.T, lstm_all.T, lag_llama_post.T, lag_llama_all.T,
                              model_1_post.T,model_2_post.T,model_3_post.T,model_4_post.T,model_5_post.T,
                              model_1_all.T,model_2_all.T,model_3_all.T,model_4_all.T,model_5_all.T], axis=1)

# %%
mean_perform_all
# Out:
#                CNN-Dataset After COVID  CNN-Entire Dataset  \
# MAE_test                     23.834865           28.168962
# RMSE_test                    30.218668           41.929634
# MAPE (%)_test                19.107530           38.637849
#
#                LSTM-Dataset After COVID  LSTM-Entire Dataset  \
# MAE_test                      25.480675            28.423190
# RMSE_test                     32.922506            41.958132
# MAPE (%)_test                 21.069957            36.191528
#
#                Lag-Llama-Dataset After COVID  Lag-Llama-Entire Dataset  \
# MAE_test                           26.158303                 36.776330
# RMSE_test                          32.677543                 50.788742
# MAPE (%)_test                      22.715593                 53.929511
#
#                Chronos(tiny)-Dataset After COVID  \
# MAE_test                               16.869719
# RMSE_test                              22.398405
# MAPE (%)_test                          13.951429
#
#                Chronos(mini)-Dataset After COVID  \
# MAE_test                               16.131548
# RMSE_test                              21.345386
# MAPE (%)_test                          13.211905
#
#                Chronos(small)-Dataset After COVID  \
# MAE_test                                14.207590
# RMSE_test                               18.984114
# MAPE (%)_test                           11.871429
#
#                Chronos(base)-Dataset After COVID  \
# MAE_test                               14.033500
# RMSE_test                              18.702486
# MAPE (%)_test                          11.688571
#
#                Chronos(large)-Dataset After COVID  \
# MAE_test                                13.810229
# RMSE_test                               18.531800
# MAPE (%)_test                           11.491429
#
#                Chronos(tiny)-Entire Dataset  Chronos(mini)-Entire Dataset  \
# MAE_test                          27.090352                     26.373133
# RMSE_test                         42.868238                     42.262348
# MAPE (%)_test                     28.548571                     27.606667
#
#                Chronos(small)-Entire Dataset  Chronos(base)-Entire Dataset  \
# MAE_test                           25.958400                     25.483905
# RMSE_test                          41.988119                     41.442076
# MAPE (%)_test                      27.345714                     26.788095
#
#                Chronos(large)-Entire Dataset
# MAE_test                           25.357190
# RMSE_test                          41.252195
# MAPE (%)_test                      26.478571

# %% [markdown]
# ## 3.3 Concatenate perform and model size

# %%
print(pd.concat([mean_param, mean_perform_all], sort=False))
# Out:
#                CNN-Dataset After COVID  CNN-Entire Dataset  \
# Model Size                50313.047619        52414.380952
# MAE_test                     23.834865           28.168962
# RMSE_test                    30.218668           41.929634
# MAPE (%)_test                19.107530           38.637849
#
#                LSTM-Dataset After COVID  LSTM-Entire Dataset
# Model Size                149217.428571        498328.285714
# MAE_test                      25.480675            28.423190
# RMSE_test                     32.922506            41.958132
# MAPE (%)_test                 21.069957            36.191528
