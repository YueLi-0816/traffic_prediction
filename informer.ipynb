# %% [markdown]
# # Recreate this virtual env, and install the latest version of required packages

# %%
#!git clone https://github.com/zhouhaoyi/Informer2020.git
#!git clone https://github.com/zhouhaoyi/ETDataset.git
# Out:
# Cloning into 'ETDataset'...
# remote: Enumerating objects: 187, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 187 (delta 25), reused 20 (delta 20), pack-reused 159 (from 1)
# Receiving objects: 100% (187/187), 3.86 MiB | 3.57 MiB/s, done.
# Resolving deltas: 100% (62/62), done.

# %%
# !{sys.executable} -m pip install matplotlib
# !{sys.executable} -m pip install pandas
# !{sys.executable} -m pip install scikit_learn
# !{sys.executable} -m pip install torch
# !{sys.executable} -m pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/yl2672496l/Yue/anaconda3/envs/transformer/lib/python3.12/site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: pandas>=1.2 in /home/yl2672496l/Yue/anaconda3/envs/transformer/lib/python3.12/site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/yl2672496l/Yue/anaconda3/envs/transformer/lib/python3.12/site-packages (from seaborn) (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in /home/yl2672496l/Yue/anaconda3/envs/transformer/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/yl2672496l/Yue/anaconda3/envs/transformer/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/yl2672496l/Yue/anaconda3/envs/transformer/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/yl2672496l/Yue/anaconda3/envs/transformer/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/yl2672496l/Yue/anaconda3/envs/transformer/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /home/yl2672496l/Yue/anaconda3/envs/transformer/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/yl2672496l/Yue/anaconda3/envs/transformer/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/yl2672496l/Yue/anaconda3/envs/transformer/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/yl2672496l/Yue/anaconda3/envs/transformer/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/yl2672496l/Yue/anaconda3/envs/transformer/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/yl2672496l/Yue/anaconda3/envs/transformer/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
import torch
print(torch.__version__)
print(torch.version.cuda)
print(torch.cuda.is_available())
# Out:
# 2.8.0+cu128
# 12.8
# True

# %%
num_gpus = torch.cuda.device_count()
print("Number of GPUs available:", num_gpus)

for i in range(num_gpus):
    gpu_name = torch.cuda.get_device_name(i)
    print(f"GPU {i}: {gpu_name}")
# Out:
# Number of GPUs available: 1
# GPU 0: NVIDIA A30

# %%
import sys
if not 'Informer2020' in sys.path:
    sys.path += ['Informer2020']

# %% [markdown]
# # Run training directly using bash

# %%
cd Informer2020
# Out:
# /home/yl2672496l/Yue/code/transformer/Informer2020

# %%
import sys 
print(sys.executable)

# %%
import sys
import os
os.environ["PATH"] = f"{sys.prefix}/bin:" + os.environ["PATH"]

# %%
# !which python

# %%
# !python -u main_informer.py --model informer --data ETTh1 --features S --seq_len 720 --label_len 168 --pred_len 24 --e_layers 2 --d_layers 1 --attn prob --des 'Exp' --itr 5
# Out:
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./ETDataset/ETT-small/', data_path='ETTh1.csv', features='S', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=720, label_len=168, pred_len=24, enc_in=1, dec_in=1, c_out=1, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='prob', embed='timeF', activation='gelu', output_attention=False, do_predict=False, mix=True, cols=None, num_workers=0, itr=5, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='Exp', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftS_sl720_ll168_pl24_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_Exp_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 7897
# val 2857
# test 2857
# 	iters: 100, epoch: 1 | loss: 0.1396151
# 	speed: 0.1314s/iter; left time: 181.0022s
# 	iters: 200, epoch: 1 | loss: 0.1057655
# 	speed: 0.1176s/iter; left time: 150.1412s
# Epoch: 1 cost time: 29.46189546585083
# Epoch: 1, Steps: 246 | Train Loss: 0.1846191 Vali Loss: 0.0789483 Test Loss: 0.1188663
# Validation loss decreased (inf --> 0.078948).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.0748101
# 	speed: 0.2674s/iter; left time: 302.4574s
# 	iters: 200, epoch: 2 | loss: 0.0699807
# 	speed: 0.1189s/iter; left time: 122.6166s
# Epoch: 2 cost time: 29.218374013900757
# Epoch: 2, Steps: 246 | Train Loss: 0.0838629 Vali Loss: 0.0926631 Test Loss: 0.1905550
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# 	iters: 100, epoch: 3 | loss: 0.0546747
# 	speed: 0.2687s/iter; left time: 237.8350s
# 	iters: 200, epoch: 3 | loss: 0.0576573
# 	speed: 0.1207s/iter; left time: 94.7697s
# Epoch: 3 cost time: 29.6236515045166
# Epoch: 3, Steps: 246 | Train Loss: 0.0582425 Vali Loss: 0.1147508 Test Loss: 0.1378915
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# 	iters: 100, epoch: 4 | loss: 0.0498972
# 	speed: 0.2725s/iter; left time: 174.1243s
# 	iters: 200, epoch: 4 | loss: 0.0501049
# 	speed: 0.1204s/iter; left time: 64.8709s
# Epoch: 4 cost time: 29.609053134918213
# Epoch: 4, Steps: 246 | Train Loss: 0.0505378 Vali Loss: 0.1169431 Test Loss: 0.1715466
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftS_sl720_ll168_pl24_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_Exp_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2857
# test shape: (89, 32, 24, 1) (89, 32, 24, 1)
# test shape: (2848, 24, 1) (2848, 24, 1)
# mse:0.11902618408203125, mae:0.27567142248153687
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftS_sl720_ll168_pl24_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_Exp_1>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 7897
# val 2857
# test 2857
# 	iters: 100, epoch: 1 | loss: 0.1518222
# 	speed: 0.1230s/iter; left time: 169.4394s
# 	iters: 200, epoch: 1 | loss: 0.1089774
# 	speed: 0.1212s/iter; left time: 154.7639s
# Epoch: 1 cost time: 30.01932191848755
# Epoch: 1, Steps: 246 | Train Loss: 0.1727169 Vali Loss: 0.1072371 Test Loss: 0.0850371
# Validation loss decreased (inf --> 0.107237).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.0990862
# 	speed: 0.2725s/iter; left time: 308.1474s
# 	iters: 200, epoch: 2 | loss: 0.0993066
# 	speed: 0.1206s/iter; left time: 124.3386s
# Epoch: 2 cost time: 29.72627854347229
# Epoch: 2, Steps: 246 | Train Loss: 0.0848009 Vali Loss: 0.0867025 Test Loss: 0.1464130
# Validation loss decreased (0.107237 --> 0.086702).  Saving model ...
# Updating learning rate to 5e-05
# 	iters: 100, epoch: 3 | loss: 0.0666558
# 	speed: 0.2732s/iter; left time: 241.7758s
# 	iters: 200, epoch: 3 | loss: 0.0484246
# 	speed: 0.1209s/iter; left time: 94.9131s
# Epoch: 3 cost time: 29.75946855545044
# Epoch: 3, Steps: 246 | Train Loss: 0.0611792 Vali Loss: 0.1201805 Test Loss: 0.1234434
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 2.5e-05
# 	iters: 100, epoch: 4 | loss: 0.0440597
# 	speed: 0.2727s/iter; left time: 174.2661s
# 	iters: 200, epoch: 4 | loss: 0.0455369
# 	speed: 0.1215s/iter; left time: 65.5012s
# Epoch: 4 cost time: 29.89622449874878
# Epoch: 4, Steps: 246 | Train Loss: 0.0522089 Vali Loss: 0.1262119 Test Loss: 0.1175677
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 1.25e-05
# 	iters: 100, epoch: 5 | loss: 0.0604374
# 	speed: 0.2740s/iter; left time: 107.6631s
# 	iters: 200, epoch: 5 | loss: 0.0458772
# 	speed: 0.1225s/iter; left time: 35.8939s
# Epoch: 5 cost time: 30.063477993011475
# Epoch: 5, Steps: 246 | Train Loss: 0.0487977 Vali Loss: 0.1204218 Test Loss: 0.1378255
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftS_sl720_ll168_pl24_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_Exp_1<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2857
# test shape: (89, 32, 24, 1) (89, 32, 24, 1)
# test shape: (2848, 24, 1) (2848, 24, 1)
# mse:0.14646296203136444, mae:0.3131720721721649
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftS_sl720_ll168_pl24_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_Exp_2>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 7897
# val 2857
# test 2857
# 	iters: 100, epoch: 1 | loss: 0.1788239
# 	speed: 0.1227s/iter; left time: 168.9940s
# 	iters: 200, epoch: 1 | loss: 0.1082839
# 	speed: 0.1224s/iter; left time: 156.2575s
# Epoch: 1 cost time: 30.177386045455933
# Epoch: 1, Steps: 246 | Train Loss: 0.1751557 Vali Loss: 0.0790675 Test Loss: 0.0991617
# Validation loss decreased (inf --> 0.079067).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.1069036
# 	speed: 0.2765s/iter; left time: 312.6682s
# 	iters: 200, epoch: 2 | loss: 0.0783814
# 	speed: 0.1223s/iter; left time: 126.0885s
# Epoch: 2 cost time: 30.115820169448853
# Epoch: 2, Steps: 246 | Train Loss: 0.0868892 Vali Loss: 0.1022280 Test Loss: 0.1836836
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# 	iters: 100, epoch: 3 | loss: 0.0647607
# 	speed: 0.2735s/iter; left time: 242.0353s
# 	iters: 200, epoch: 3 | loss: 0.0781412
# 	speed: 0.1214s/iter; left time: 95.3036s
# Epoch: 3 cost time: 29.86184573173523
# Epoch: 3, Steps: 246 | Train Loss: 0.0623043 Vali Loss: 0.1111732 Test Loss: 0.2110659
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# 	iters: 100, epoch: 4 | loss: 0.0597772
# 	speed: 0.2731s/iter; left time: 174.4863s
# 	iters: 200, epoch: 4 | loss: 0.0579936
# 	speed: 0.1223s/iter; left time: 65.9287s
# Epoch: 4 cost time: 30.018275499343872
# Epoch: 4, Steps: 246 | Train Loss: 0.0542150 Vali Loss: 0.1176238 Test Loss: 0.2140607
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftS_sl720_ll168_pl24_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_Exp_2<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2857
# test shape: (89, 32, 24, 1) (89, 32, 24, 1)
# test shape: (2848, 24, 1) (2848, 24, 1)
# mse:0.09906790405511856, mae:0.24947811663150787
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftS_sl720_ll168_pl24_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_Exp_3>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 7897
# val 2857
# test 2857
# 	iters: 100, epoch: 1 | loss: 0.1670983
# 	speed: 0.1215s/iter; left time: 167.3207s
# 	iters: 200, epoch: 1 | loss: 0.0703092
# 	speed: 0.1237s/iter; left time: 157.9402s
# Epoch: 1 cost time: 30.326393842697144
# Epoch: 1, Steps: 246 | Train Loss: 0.1745287 Vali Loss: 0.1044897 Test Loss: 0.0990070
# Validation loss decreased (inf --> 0.104490).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.0970963
# 	speed: 0.2819s/iter; left time: 318.8152s
# 	iters: 200, epoch: 2 | loss: 0.0741262
# 	speed: 0.1219s/iter; left time: 125.6523s
# Epoch: 2 cost time: 30.18295407295227
# Epoch: 2, Steps: 246 | Train Loss: 0.0843135 Vali Loss: 0.0919837 Test Loss: 0.2199356
# Validation loss decreased (0.104490 --> 0.091984).  Saving model ...
# Updating learning rate to 5e-05
# 	iters: 100, epoch: 3 | loss: 0.0789806
# 	speed: 0.2778s/iter; left time: 245.8208s
# 	iters: 200, epoch: 3 | loss: 0.0580706
# 	speed: 0.1229s/iter; left time: 96.4429s
# Epoch: 3 cost time: 30.168256282806396
# Epoch: 3, Steps: 246 | Train Loss: 0.0609028 Vali Loss: 0.1096018 Test Loss: 0.2307562
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 2.5e-05
# 	iters: 100, epoch: 4 | loss: 0.0670034
# 	speed: 0.2732s/iter; left time: 174.5479s
# 	iters: 200, epoch: 4 | loss: 0.0679405
# 	speed: 0.1209s/iter; left time: 65.1434s
# Epoch: 4 cost time: 29.81953263282776
# Epoch: 4, Steps: 246 | Train Loss: 0.0529939 Vali Loss: 0.1137297 Test Loss: 0.2292562
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 1.25e-05
# 	iters: 100, epoch: 5 | loss: 0.0462646
# 	speed: 0.2768s/iter; left time: 108.7993s
# 	iters: 200, epoch: 5 | loss: 0.0462014
# 	speed: 0.1228s/iter; left time: 35.9792s
# Epoch: 5 cost time: 30.194787979125977
# Epoch: 5, Steps: 246 | Train Loss: 0.0493815 Vali Loss: 0.1237546 Test Loss: 0.1856886
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftS_sl720_ll168_pl24_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_Exp_3<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2857
# test shape: (89, 32, 24, 1) (89, 32, 24, 1)
# test shape: (2848, 24, 1) (2848, 24, 1)
# mse:0.22002263367176056, mae:0.3968621790409088
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftS_sl720_ll168_pl24_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_Exp_4>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 7897
# val 2857
# test 2857
# 	iters: 100, epoch: 1 | loss: 0.1209350
# 	speed: 0.1212s/iter; left time: 166.8896s
# 	iters: 200, epoch: 1 | loss: 0.1047726
# 	speed: 0.1232s/iter; left time: 157.3618s
# Epoch: 1 cost time: 30.121838569641113
# Epoch: 1, Steps: 246 | Train Loss: 0.1810923 Vali Loss: 0.0790831 Test Loss: 0.1240160
# Validation loss decreased (inf --> 0.079083).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.0935206
# 	speed: 0.2803s/iter; left time: 316.9917s
# 	iters: 200, epoch: 2 | loss: 0.0537647
# 	speed: 0.1220s/iter; left time: 125.7870s
# Epoch: 2 cost time: 30.236640691757202
# Epoch: 2, Steps: 246 | Train Loss: 0.0906869 Vali Loss: 0.0889583 Test Loss: 0.2319331
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# 	iters: 100, epoch: 3 | loss: 0.0682929
# 	speed: 0.2750s/iter; left time: 243.3373s
# 	iters: 200, epoch: 3 | loss: 0.0664785
# 	speed: 0.1220s/iter; left time: 95.7585s
# Epoch: 3 cost time: 29.962714672088623
# Epoch: 3, Steps: 246 | Train Loss: 0.0647434 Vali Loss: 0.0992873 Test Loss: 0.2969401
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# 	iters: 100, epoch: 4 | loss: 0.0451465
# 	speed: 0.2735s/iter; left time: 174.7881s
# 	iters: 200, epoch: 4 | loss: 0.0433534
# 	speed: 0.1223s/iter; left time: 65.9277s
# Epoch: 4 cost time: 29.996320486068726
# Epoch: 4, Steps: 246 | Train Loss: 0.0541629 Vali Loss: 0.1028444 Test Loss: 0.2857956
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftS_sl720_ll168_pl24_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_Exp_4<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2857
# test shape: (89, 32, 24, 1) (89, 32, 24, 1)
# test shape: (2848, 24, 1) (2848, 24, 1)
# mse:0.1241493821144104, mae:0.28732043504714966

# %% [markdown]
# # Experiments: Train and Test

# %%
from utils.tools import dotdict
from exp.exp_informer import Exp_Informer
import torch

# %%
args = dotdict()

args.model = 'informer' # model of experiment, options: [informer, informerstack, informerlight(TBD)]

args.data = 'ETTh1' # data
args.root_path = './ETDataset/ETT-small/' # root path of data file
args.data_path = 'ETTh1.csv' # data file
args.features = 'M' # forecasting task, options:[M, S, MS]; M:multivariate predict multivariate, S:univariate predict univariate, MS:multivariate predict univariate
args.target = 'OT' # target feature in S or MS task
args.freq = 'h' # freq for time features encoding, options:[s:secondly, t:minutely, h:hourly, d:daily, b:business days, w:weekly, m:monthly], you can also use more detailed freq like 15min or 3h
args.checkpoints = './informer_checkpoints' # location of model checkpoints

args.seq_len = 96 # input sequence length of Informer encoder
args.label_len = 48 # start token length of Informer decoder
args.pred_len = 24 # prediction sequence length
# Informer decoder input: concat[start token series(label_len), zero padding series(pred_len)]

args.enc_in = 7 # encoder input size
args.dec_in = 7 # decoder input size
args.c_out = 7 # output size
args.factor = 5 # probsparse attn factor
args.d_model = 512 # dimension of model
args.n_heads = 8 # num of heads
args.e_layers = 2 # num of encoder layers
args.d_layers = 1 # num of decoder layers
args.d_ff = 2048 # dimension of fcn in model
args.dropout = 0.05 # dropout
args.attn = 'prob' # attention used in encoder, options:[prob, full]
args.embed = 'timeF' # time features encoding, options:[timeF, fixed, learned]
args.activation = 'gelu' # activation
args.distil = True # whether to use distilling in encoder
args.output_attention = False # whether to output attention in ecoder
args.mix = True
args.padding = 0
args.freq = 'h'

args.batch_size = 32 
args.learning_rate = 0.0001
args.loss = 'mse'
args.lradj = 'type1'
args.use_amp = False # whether to use automatic mixed precision training

args.num_workers = 0
args.itr = 1
args.train_epochs = 6
args.patience = 3
args.des = 'exp'

args.use_gpu = True if torch.cuda.is_available() else False
args.gpu = 0

args.use_multi_gpu = False
args.devices = '0,1,2,3'

# %%
args.use_gpu = True if torch.cuda.is_available() and args.use_gpu else False

if args.use_gpu and args.use_multi_gpu:
    args.devices = args.devices.replace(' ','')
    device_ids = args.devices.split(',')
    args.device_ids = [int(id_) for id_ in device_ids]
    args.gpu = args.device_ids[0]

# %%
# Set augments by using data name
data_parser = {
    'ETTh1':{'data':'ETTh1.csv','T':'OT','M':[7,7,7],'S':[1,1,1],'MS':[7,7,1]},
    'ETTh2':{'data':'ETTh2.csv','T':'OT','M':[7,7,7],'S':[1,1,1],'MS':[7,7,1]},
    'ETTm1':{'data':'ETTm1.csv','T':'OT','M':[7,7,7],'S':[1,1,1],'MS':[7,7,1]},
    'ETTm2':{'data':'ETTm2.csv','T':'OT','M':[7,7,7],'S':[1,1,1],'MS':[7,7,1]},
}
if args.data in data_parser.keys():
    data_info = data_parser[args.data]
    args.data_path = data_info['data']
    args.target = data_info['T']
    args.enc_in, args.dec_in, args.c_out = data_info[args.features]

# %%
args.detail_freq = args.freq
args.freq = args.freq[-1:]

# %%
print('Args in experiment:')
print(args)
# Out:
# Args in experiment:
# {'model': 'informer', 'data': 'ETTh1', 'root_path': './ETDataset/ETT-small/', 'data_path': 'ETTh1.csv', 'features': 'M', 'target': 'OT', 'freq': 'h', 'checkpoints': './informer_checkpoints', 'seq_len': 96, 'label_len': 48, 'pred_len': 24, 'enc_in': 7, 'dec_in': 7, 'c_out': 7, 'factor': 5, 'd_model': 512, 'n_heads': 8, 'e_layers': 2, 'd_layers': 1, 'd_ff': 2048, 'dropout': 0.05, 'attn': 'prob', 'embed': 'timeF', 'activation': 'gelu', 'distil': True, 'output_attention': False, 'mix': True, 'padding': 0, 'batch_size': 32, 'learning_rate': 0.0001, 'loss': 'mse', 'lradj': 'type1', 'use_amp': False, 'num_workers': 0, 'itr': 1, 'train_epochs': 6, 'patience': 3, 'des': 'exp', 'use_gpu': True, 'gpu': 0, 'use_multi_gpu': False, 'devices': '0,1,2,3', 'detail_freq': 'h'}

# %%
Exp = Exp_Informer

# %%
for ii in range(args.itr):
    # setting record of experiments
    setting = '{}_{}_ft{}_sl{}_ll{}_pl{}_dm{}_nh{}_el{}_dl{}_df{}_at{}_fc{}_eb{}_dt{}_mx{}_{}_{}'.format(args.model, args.data, args.features, 
                args.seq_len, args.label_len, args.pred_len,
                args.d_model, args.n_heads, args.e_layers, args.d_layers, args.d_ff, args.attn, args.factor, args.embed, args.distil, args.mix, args.des, ii)

    # set experiments
    exp = Exp(args)
    
    # train
    print('>>>>>>>start training : {}>>>>>>>>>>>>>>>>>>>>>>>>>>'.format(setting))
    exp.train(setting)
    
    # test
    print('>>>>>>>testing : {}<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<'.format(setting))
    exp.test(setting)

    torch.cuda.empty_cache()
# Out:
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl24_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8521
# val 2857
# test 2857
# 	iters: 100, epoch: 1 | loss: 0.4552747
# 	speed: 0.0492s/iter; left time: 73.6696s
# 	iters: 200, epoch: 1 | loss: 0.2803553
# 	speed: 0.0332s/iter; left time: 46.3739s
# Epoch: 1 cost time: 9.543526649475098
# Epoch: 1, Steps: 266 | Train Loss: 0.4159421 Vali Loss: 0.6808864 Test Loss: 0.5264542
# Validation loss decreased (inf --> 0.680886).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.2751176
# 	speed: 0.0849s/iter; left time: 104.4916s
# 	iters: 200, epoch: 2 | loss: 0.2408546
# 	speed: 0.0360s/iter; left time: 40.6877s
# Epoch: 2 cost time: 9.492535591125488
# Epoch: 2, Steps: 266 | Train Loss: 0.2574130 Vali Loss: 0.6979954 Test Loss: 0.6694005
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# 	iters: 100, epoch: 3 | loss: 0.2104226
# 	speed: 0.0823s/iter; left time: 79.4443s
# 	iters: 200, epoch: 3 | loss: 0.2447424
# 	speed: 0.0354s/iter; left time: 30.5859s
# Epoch: 3 cost time: 9.352406978607178
# Epoch: 3, Steps: 266 | Train Loss: 0.1971946 Vali Loss: 0.6331654 Test Loss: 0.7089570
# Validation loss decreased (0.680886 --> 0.633165).  Saving model ...
# Updating learning rate to 2.5e-05
# 	iters: 100, epoch: 4 | loss: 0.1890262
# 	speed: 0.0841s/iter; left time: 58.7633s
# 	iters: 200, epoch: 4 | loss: 0.1829882
# 	speed: 0.0337s/iter; left time: 20.1605s
# Epoch: 4 cost time: 8.939173221588135
# Epoch: 4, Steps: 266 | Train Loss: 0.1707470 Vali Loss: 0.6633514 Test Loss: 0.7034675
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 1.25e-05
# 	iters: 100, epoch: 5 | loss: 0.1689454
# 	speed: 0.0775s/iter; left time: 33.5526s
# 	iters: 200, epoch: 5 | loss: 0.1410704
# 	speed: 0.0325s/iter; left time: 10.8097s
# Epoch: 5 cost time: 8.637527227401733
# Epoch: 5, Steps: 266 | Train Loss: 0.1571862 Vali Loss: 0.6852944 Test Loss: 0.7519606
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 6.25e-06
# 	iters: 100, epoch: 6 | loss: 0.1426774
# 	speed: 0.0757s/iter; left time: 12.6350s
# 	iters: 200, epoch: 6 | loss: 0.1479650
# 	speed: 0.0320s/iter; left time: 2.1440s
# Epoch: 6 cost time: 8.448928117752075
# Epoch: 6, Steps: 266 | Train Loss: 0.1507183 Vali Loss: 0.6934914 Test Loss: 0.7835738
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl24_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2857
# test shape: (89, 32, 24, 7) (89, 32, 24, 7)
# test shape: (2848, 24, 7) (2848, 24, 7)
# mse:0.7067388892173767, mae:0.595707893371582

# %% [markdown]
# # Prediction

# %%
import os

# set saved model path
setting = 'informer_ETTh1_ftM_sl96_ll48_pl24_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_0'
# path = os.path.join(args.checkpoints,setting,'checkpoint.pth')

# %%
# If you already have a trained model, you can set the arguments and model path, then initialize a Experiment and use it to predict
# Prediction is a sequence which is adjacent to the last date of the data, and does not exist in the data
# If you want to get more information about prediction, you can refer to code `exp/exp_informer.py function predict()` and `data/data_loader.py class Dataset_Pred`

exp = Exp(args)

exp.predict(setting, True)
# Out:
# Use GPU: cuda:0
# pred 1

# %%
# the prediction will be saved in ./results/{setting}/real_prediction.npy
import numpy as np

prediction = np.load('./results/'+setting+'/real_prediction.npy')

prediction.shape
# Out:
# (1, 24, 7)

# %% [markdown]
# ## More details about Prediction - prediction function

# %%
# here is the detailed code of function predict

def predict(exp, setting, load=False):
    pred_data, pred_loader = exp._get_data(flag='pred')
        
    if load:
        path = os.path.join(exp.args.checkpoints, setting)
        best_model_path = path+'/'+'checkpoint.pth'
        exp.model.load_state_dict(torch.load(best_model_path))

    exp.model.eval()
        
    preds = []
        
    for i, (batch_x,batch_y,batch_x_mark,batch_y_mark) in enumerate(pred_loader):
        batch_x = batch_x.float().to(exp.device)
        batch_y = batch_y.float()
        batch_x_mark = batch_x_mark.float().to(exp.device)
        batch_y_mark = batch_y_mark.float().to(exp.device)

        # decoder input
        if exp.args.padding==0:
            dec_inp = torch.zeros([batch_y.shape[0], exp.args.pred_len, batch_y.shape[-1]]).float()
        elif exp.args.padding==1:
            dec_inp = torch.ones([batch_y.shape[0], exp.args.pred_len, batch_y.shape[-1]]).float()
        else:
            dec_inp = torch.zeros([batch_y.shape[0], exp.args.pred_len, batch_y.shape[-1]]).float()
        dec_inp = torch.cat([batch_y[:,:exp.args.label_len,:], dec_inp], dim=1).float().to(exp.device)
        # encoder - decoder
        if exp.args.use_amp:
            with torch.cuda.amp.autocast():
                if exp.args.output_attention:
                    outputs = exp.model(batch_x, batch_x_mark, dec_inp, batch_y_mark)[0]
                else:
                    outputs = exp.model(batch_x, batch_x_mark, dec_inp, batch_y_mark)
        else:
            if exp.args.output_attention:
                outputs = exp.model(batch_x, batch_x_mark, dec_inp, batch_y_mark)[0]
            else:
                outputs = exp.model(batch_x, batch_x_mark, dec_inp, batch_y_mark)
        f_dim = -1 if exp.args.features=='MS' else 0
        batch_y = batch_y[:,-exp.args.pred_len:,f_dim:].to(exp.device)
        
        pred = outputs.detach().cpu().numpy()#.squeeze()
        
        preds.append(pred)

    preds = np.array(preds)
    preds = preds.reshape(-1, preds.shape[-2], preds.shape[-1])
    
    # result save
    folder_path = './results/' + setting +'/'
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)
    
    np.save(folder_path+'real_prediction.npy', preds)
    
    return preds

# %%
# you can also use this prediction function to get result
prediction = predict(exp, setting, True)
# Out:
# pred 1

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(prediction[0,:,-1])
plt.show()

# %% [markdown]
# ## More details about Prediction - prediction dataset
#
# You can give a `root_path` and `data_path` of the data you want to forecast, and set `seq_len`, `label_len`, `pred_len` and other arguments as other Dataset. The difference is that you can set a more detailed freq such as `15min` or `3h` to generate the timestamp of prediction series.
#
# `Dataset_Pred` only has one sample (including `encoder_input: [1, seq_len, dim]`, `decoder_token: [1, label_len, dim]`, `encoder_input_timestamp: [1, seq_len, date_dim]`, `decoder_input_timstamp: [1, label_len+pred_len, date_dim]`). It will intercept the last sequence of the given data (seq_len data) to forecast the unseen future sequence (pred_len data).

# %%
from data.data_loader import Dataset_Pred
from torch.utils.data import DataLoader

# %%
Data = Dataset_Pred
timeenc = 0 if args.embed!='timeF' else 1
flag = 'pred'; shuffle_flag = False; drop_last = False; batch_size = 1

freq = args.detail_freq

data_set = Data(
    root_path=args.root_path,
    data_path=args.data_path,
    flag=flag,
    size=[args.seq_len, args.label_len, args.pred_len],
    features=args.features,
    target=args.target,
    timeenc=timeenc,
    freq=freq
)
data_loader = DataLoader(
    data_set,
    batch_size=batch_size,
    shuffle=shuffle_flag,
    num_workers=args.num_workers,
    drop_last=drop_last)

# %%
len(data_set), len(data_loader)
# Out:
# (1, 1)

# %% [markdown]
# # Visualization

# %%
# When we finished exp.train(setting) and exp.test(setting), we will get a trained model and the results of test experiment
# The results of test experiment will be saved in ./results/{setting}/pred.npy (prediction of test dataset) and ./results/{setting}/true.npy (groundtruth of test dataset)

preds = np.load('./results/'+setting+'/pred.npy')
trues = np.load('./results/'+setting+'/true.npy')

# [samples, pred_len, dimensions]
preds.shape, trues.shape
# Out:
# ((2848, 24, 7), (2848, 24, 7))

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# draw OT prediction
plt.figure()
plt.plot(trues[0,:,-1], label='GroundTruth')
plt.plot(preds[0,:,-1], label='Prediction')
plt.legend()
plt.show()

# %%
# draw HUFL prediction
plt.figure()
plt.plot(trues[0,:,0], label='GroundTruth')
plt.plot(preds[0,:,0], label='Prediction')
plt.legend()
plt.show()

# %%
from data.data_loader import Dataset_ETT_hour
from torch.utils.data import DataLoader

Data = Dataset_ETT_hour
timeenc = 0 if args.embed!='timeF' else 1
flag = 'test'; shuffle_flag = False; drop_last = True; batch_size = 1

data_set = Data(
    root_path=args.root_path,
    data_path=args.data_path,
    flag=flag,
    size=[args.seq_len, args.label_len, args.pred_len],
    features=args.features,
    timeenc=timeenc,
    freq=args.freq
)
data_loader = DataLoader(
    data_set,
    batch_size=batch_size,
    shuffle=shuffle_flag,
    num_workers=args.num_workers,
    drop_last=drop_last)

# %%
import os

args.output_attention = True

exp = Exp(args)

model = exp.model

setting = 'informer_ETTh1_ftM_sl96_ll48_pl24_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_0'
path = os.path.join(args.checkpoints,setting,'checkpoint.pth')
model.load_state_dict(torch.load(path))
# Out:
# Use GPU: cuda:0
# <All keys matched successfully>

# %%
# attention visualization
idx = 0
for i, (batch_x,batch_y,batch_x_mark,batch_y_mark) in enumerate(data_loader):
    if i!=idx:
        continue
    batch_x = batch_x.float().to(exp.device)
    batch_y = batch_y.float()

    batch_x_mark = batch_x_mark.float().to(exp.device)
    batch_y_mark = batch_y_mark.float().to(exp.device)
    
    dec_inp = torch.zeros_like(batch_y[:,-args.pred_len:,:]).float()
    dec_inp = torch.cat([batch_y[:,:args.label_len,:], dec_inp], dim=1).float().to(exp.device)
    
    outputs,attn = model(batch_x, batch_x_mark, dec_inp, batch_y_mark)

# %%
attn[0].shape, attn[1].shape #, attn[2].shape
# Out:
# (torch.Size([1, 8, 96, 96]), torch.Size([1, 8, 48, 48]))

# %%
layer = 0
distil = 'Distil' if args.distil else 'NoDistil'
for h in range(0,8):
    plt.figure(figsize=[10,8])
    plt.title('Informer, {}, attn:{} layer:{} head:{}'.format(distil, args.attn, layer, h))
    A = attn[layer][0,h].detach().cpu().numpy()
    ax = sns.heatmap(A, vmin=0, vmax=A.max()+0.01)
    plt.show()

# %%
layer = 1
distil = 'Distil' if args.distil else 'NoDistil'
for h in range(0,8):
    plt.figure(figsize=[10,8])
    plt.title('Informer, {}, attn:{} layer:{} head:{}'.format(distil, args.attn, layer, h))
    A = attn[layer][0,h].detach().cpu().numpy()
    ax = sns.heatmap(A, vmin=0, vmax=A.max()+0.01)
    plt.show()

# %% [markdown]
# # Custom Data
#
# Custom data (xxx.csv) has to include at least 2 features: `date`(format: `YYYY-MM-DD hh:mm:ss`) and `target feature`.

# %%
from data.data_loader import Dataset_Custom
from torch.utils.data import DataLoader
import pandas as pd
import os

# %%
# custom data: xxx.csv
# data features: ['date', ...(other features), target feature]

# we take ETTh2 as an example
args.root_path = './ETDataset/ETT-small/'
args.data_path = 'ETTh2.csv'

df = pd.read_csv(os.path.join(args.root_path, args.data_path))

# %%
df.head()
# Out:
#                   date       HUFL    HULL       MUFL   MULL   LUFL   LULL  \
# 0  2016-07-01 00:00:00  41.130001  12.481  36.535999  9.355  4.424  1.311
# 1  2016-07-01 01:00:00  37.528000  10.136  33.936001  7.532  4.435  1.215
# 2  2016-07-01 02:00:00  37.946999  11.309  35.330002  9.007  2.100  0.000
# 3  2016-07-01 03:00:00  38.952000  11.895  35.543999  9.436  3.380  1.215
# 4  2016-07-01 04:00:00  38.113998  11.476  35.410000  9.623  2.036  0.000
#
#           OT
# 0  38.661999
# 1  37.124001
# 2  36.465000
# 3  33.608501
# 4  31.850500

# %%
'''
We set 'HULL' as target instead of 'OT'

The following frequencies are supported:
        Y   - yearly
            alias: A
        M   - monthly
        W   - weekly
        D   - daily
        B   - business days
        H   - hourly
        T   - minutely
            alias: min
        S   - secondly
'''

args.target = 'HULL'
args.freq = 'h'

Data = Dataset_Custom
timeenc = 0 if args.embed!='timeF' else 1
flag = 'test'; shuffle_flag = False; drop_last = True; batch_size = 1

data_set = Data(
    root_path=args.root_path,
    data_path=args.data_path,
    flag=flag,
    size=[args.seq_len, args.label_len, args.pred_len],
    features=args.features,
    timeenc=timeenc,
    target=args.target, # HULL here
    freq=args.freq # 'h': hourly, 't':minutely
)
data_loader = DataLoader(
    data_set,
    batch_size=batch_size,
    shuffle=shuffle_flag,
    num_workers=args.num_workers,
    drop_last=drop_last)

# %%
batch_x,batch_y,batch_x_mark,batch_y_mark = data_set[0]
